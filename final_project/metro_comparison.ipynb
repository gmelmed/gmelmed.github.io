# %%
import pandas as pd

# %%
metros = pd.read_csv('data/zori_metro_long_clean.csv')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2255.133793  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1814.136486  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1356.915213  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1090.919667  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1229.410303  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5945  Salt Lake City, UT  2024-12-01  1650.452457  40.7776 -111.9311
# 5946        Hartford, CT  2024-12-01  1874.958152  41.7661  -72.6834
# 5947         Buffalo, NY  2024-12-01  1344.539267  42.9018  -78.8487
# 5948      Birmingham, AL  2024-12-01  1365.603146  33.5279  -86.7971
# 5949    Grand Rapids, MI  2024-12-01  1679.715934  42.9619  -85.6562
#
#         pop_2023
# 0     19498249.0
# 1     12799100.0
# 2      9262825.0
# 3      8100037.0
# 4      7510253.0
# ...          ...
# 5945   1267864.0
# 5946   1151543.0
# 5947   1155604.0
# 5948   1184290.0
# 5949   1162950.0
#
# [5950 rows x 6 columns]

# %%
# get state name col from `name` col with everything after the last comma and space
metros['state'] = metros['name'].str.extract(r',\s(.*)$')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2255.133793  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1814.136486  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1356.915213  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1090.919667  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1229.410303  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5945  Salt Lake City, UT  2024-12-01  1650.452457  40.7776 -111.9311
# 5946        Hartford, CT  2024-12-01  1874.958152  41.7661  -72.6834
# 5947         Buffalo, NY  2024-12-01  1344.539267  42.9018  -78.8487
# 5948      Birmingham, AL  2024-12-01  1365.603146  33.5279  -86.7971
# 5949    Grand Rapids, MI  2024-12-01  1679.715934  42.9619  -85.6562
#
#         pop_2023 state
# 0     19498249.0    NY
# 1     12799100.0    CA
# 2      9262825.0    IL
# 3      8100037.0    TX
# 4      7510253.0    TX
# ...          ...   ...
# 5945   1267864.0    UT
# 5946   1151543.0    CT
# 5947   1155604.0    NY
# 5948   1184290.0    AL
# 5949   1162950.0    MI
#
# [5950 rows x 7 columns]

# %%
# import regions df
regions = pd.read_csv('data/regions.csv')

# %%
# merge metros and regions on state
metros = metros.merge(regions, on='state', how='left')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2255.133793  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1814.136486  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1356.915213  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1090.919667  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1229.410303  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5945  Salt Lake City, UT  2024-12-01  1650.452457  40.7776 -111.9311
# 5946        Hartford, CT  2024-12-01  1874.958152  41.7661  -72.6834
# 5947         Buffalo, NY  2024-12-01  1344.539267  42.9018  -78.8487
# 5948      Birmingham, AL  2024-12-01  1365.603146  33.5279  -86.7971
# 5949    Grand Rapids, MI  2024-12-01  1679.715934  42.9619  -85.6562
#
#         pop_2023 state     region
# 0     19498249.0    NY   Northest
# 1     12799100.0    CA       West
# 2      9262825.0    IL    Midwest
# 3      8100037.0    TX  Southwest
# 4      7510253.0    TX  Southwest
# ...          ...   ...        ...
# 5945   1267864.0    UT       West
# 5946   1151543.0    CT   Northest
# 5947   1155604.0    NY   Northest
# 5948   1184290.0    AL  Southeast
# 5949   1162950.0    MI    Midwest
#
# [5950 rows x 8 columns]

# %%
# Set the base zori value for each name in January 2016 to 100
base_zori = metros[metros['date'] == '2020-01-01'].set_index('name')['zori']

# Calculate the zori_index
metros['zori_index'] = metros.apply(lambda row: (row['zori'] / base_zori[row['name']]) * 100 if row['name'] in base_zori else None, axis=1)

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2255.133793  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1814.136486  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1356.915213  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1090.919667  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1229.410303  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5945  Salt Lake City, UT  2024-12-01  1650.452457  40.7776 -111.9311
# 5946        Hartford, CT  2024-12-01  1874.958152  41.7661  -72.6834
# 5947         Buffalo, NY  2024-12-01  1344.539267  42.9018  -78.8487
# 5948      Birmingham, AL  2024-12-01  1365.603146  33.5279  -86.7971
# 5949    Grand Rapids, MI  2024-12-01  1679.715934  42.9619  -85.6562
#
#         pop_2023 state     region  zori_index
# 0     19498249.0    NY   Northest   88.223126
# 1     12799100.0    CA       West   77.690480
# 2      9262825.0    IL    Midwest   88.238184
# 3      8100037.0    TX  Southwest   81.155455
# 4      7510253.0    TX  Southwest   89.895480
# ...          ...   ...        ...         ...
# 5945   1267864.0    UT       West  134.503890
# 5946   1151543.0    CT   Northest  145.377624
# 5947   1155604.0    NY   Northest  141.337316
# 5948   1184290.0    AL  Southeast  133.898620
# 5949   1162950.0    MI    Midwest  141.489244
#
# [5950 rows x 9 columns]

# %%
metros.to_csv('data/zori_metro_indexed_long.csv', index=False)

# %%
# import the homebuilding data
homebuilding = pd.read_csv('data/homebuilding_zori.csv')

homebuilding
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2019-11-01     Atlanta, GA  1819.0    30513.0       1828.0
# 1     2019-12-01     Atlanta, GA  2388.0    32729.0       2401.0
# 2     2020-01-01     Atlanta, GA  2912.0     2912.0       2932.0
# 3     2020-02-01     Atlanta, GA  2742.0     5661.0       2758.0
# 4     2020-03-01     Atlanta, GA  2216.0     7883.0       2227.0
# ...          ...             ...     ...        ...          ...
# 3045  2024-07-01  Washington, DC  1983.0    13587.0       2006.0
# 3046  2024-08-01  Washington, DC  2137.0    15660.0       2159.0
# 3047  2024-09-01  Washington, DC   900.0    16477.0        910.0
# 3048  2024-10-01  Washington, DC  1801.0    19004.0       1813.0
# 3049  2024-11-01  Washington, DC  1124.0    20058.0       1135.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0             30677.0   1819.0    1828.0  1376.046670  33.7628  ...
# 1             32898.0   4207.0    4229.0  1373.491783  33.7628  ...
# 2              2932.0   7119.0    7161.0  1373.374324  33.7628  ...
# 3              5694.0   9861.0    9919.0  1378.194661  33.7628  ...
# 4              7929.0  12077.0   12146.0  1386.720356  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 3045          13728.0  22572.0   22822.0  2365.897539  38.9047  ...
# 3046          15822.0  22460.0   22694.0  2381.806738  38.9047  ...
# 3047          16648.0  21885.0   22115.0  2390.051806  38.9047  ...
# 3048          19185.0  21838.0   22060.0  2389.848641  38.9047  ...
# 3049          20249.0  21457.0   21670.0  2379.846903  38.9047  ...
#
#        pop_2023  total_pc  total_ytd_pc  multi_total_pc  multi_total_ytd_pc  \
# 0     6307261.0  0.288398      4.837758        0.289825            4.863759
# 1     6307261.0  0.378611      5.189099        0.380672            5.215893
# 2     6307261.0  0.461690      0.461690        0.464861            0.464861
# 3     6307261.0  0.434737      0.897537        0.437274            0.902769
# 4     6307261.0  0.351341      1.249829        0.353085            1.257123
# ...         ...       ...           ...             ...                 ...
# 3045  6304975.0  0.314514      2.154965        0.318161            2.177328
# 3046  6304975.0  0.338939      2.483753        0.342428            2.509447
# 3047  6304975.0  0.142744      2.613333        0.144330            2.640455
# 3048  6304975.0  0.285647      3.014128        0.287551            3.042835
# 3049  6304975.0  0.178272      3.181297        0.180017            3.211591
#
#          rt_pc  multi_rt_pc  zori_yoy  state     region
# 0     0.288398     0.289825       NaN     GA  Southeast
# 1     0.667009     0.670497       NaN     GA  Southeast
# 2     1.128699     1.135358       NaN     GA  Southeast
# 3     1.563436     1.572632       NaN     GA  Southeast
# 4     1.914777     1.925717       NaN     GA  Southeast
# ...        ...          ...       ...    ...        ...
# 3045  3.580030     3.619681  0.050730     DC   Northest
# 3046  3.562266     3.599380  0.050124     DC   Northest
# 3047  3.471068     3.507548  0.049168     DC   Northest
# 3048  3.463614     3.498824  0.047615     DC   Northest
# 3049  3.403186     3.436968  0.044880     DC   Northest
#
# [3050 rows x 21 columns]

# %%
# Pivot the homebuilding dataframe to have dates as rows and metro areas as columns
pivot_homebuilding = homebuilding.pivot(index='date', columns='name', values='total')

# Find the earliest date where all values are non-null
earliest_date = pivot_homebuilding.dropna().index.min()

print(earliest_date)
# Out:
# 2019-11-01

# %%
# Filter the data to include only records from 2020 onwards
homebuilding_2020 = homebuilding[homebuilding['date'] >= '2020-01-01']

# Calculate the running total for each metro area
homebuilding_2020['running_total'] = homebuilding_2020.groupby('name')['total'].cumsum()

homebuilding_2020
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gn/T/ipykernel_60425/1378624272.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   homebuilding_2020['running_total'] = homebuilding_2020.groupby('name')['total'].cumsum()
#             date            name   total  total_ytd  multi_total  \
# 2     2020-01-01     Atlanta, GA  2912.0     2912.0       2932.0
# 3     2020-02-01     Atlanta, GA  2742.0     5661.0       2758.0
# 4     2020-03-01     Atlanta, GA  2216.0     7883.0       2227.0
# 5     2020-04-01     Atlanta, GA  1827.0     9633.0       1830.0
# 6     2020-05-01     Atlanta, GA  1970.0    11641.0       1982.0
# ...          ...             ...     ...        ...          ...
# 3045  2024-07-01  Washington, DC  1983.0    13587.0       2006.0
# 3046  2024-08-01  Washington, DC  2137.0    15660.0       2159.0
# 3047  2024-09-01  Washington, DC   900.0    16477.0        910.0
# 3048  2024-10-01  Washington, DC  1801.0    19004.0       1813.0
# 3049  2024-11-01  Washington, DC  1124.0    20058.0       1135.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  total_pc  \
# 2              2932.0   7119.0    7161.0  1373.374324  33.7628  ...  0.461690
# 3              5694.0   9861.0    9919.0  1378.194661  33.7628  ...  0.434737
# 4              7929.0  12077.0   12146.0  1386.720356  33.7628  ...  0.351341
# 5              9675.0  13904.0   13976.0  1394.803270  33.7628  ...  0.289666
# 6             11696.0  15874.0   15958.0  1397.741606  33.7628  ...  0.312338
# ...               ...      ...       ...          ...      ...  ...       ...
# 3045          13728.0  22572.0   22822.0  2365.897539  38.9047  ...  0.314514
# 3046          15822.0  22460.0   22694.0  2381.806738  38.9047  ...  0.338939
# 3047          16648.0  21885.0   22115.0  2390.051806  38.9047  ...  0.142744
# 3048          19185.0  21838.0   22060.0  2389.848641  38.9047  ...  0.285647
# 3049          20249.0  21457.0   21670.0  2379.846903  38.9047  ...  0.178272
#
#       total_ytd_pc  multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  \
# 2         0.461690        0.464861            0.464861  1.128699     1.135358
# 3         0.897537        0.437274            0.902769  1.563436     1.572632
# 4         1.249829        0.353085            1.257123  1.914777     1.925717
# 5         1.527287        0.290142            1.533946  2.204443     2.215859
# 6         1.845651        0.314241            1.854371  2.516782     2.530100
# ...            ...             ...                 ...       ...          ...
# 3045      2.154965        0.318161            2.177328  3.580030     3.619681
# 3046      2.483753        0.342428            2.509447  3.562266     3.599380
# 3047      2.613333        0.144330            2.640455  3.471068     3.507548
# 3048      3.014128        0.287551            3.042835  3.463614     3.498824
# 3049      3.181297        0.180017            3.211591  3.403186     3.436968
#
#       zori_yoy  state     region running_total
# 2          NaN     GA  Southeast        2912.0
# 3          NaN     GA  Southeast        5654.0
# 4          NaN     GA  Southeast        7870.0
# 5          NaN     GA  Southeast        9697.0
# 6          NaN     GA  Southeast       11667.0
# ...        ...    ...        ...           ...
# 3045  0.050730     DC   Northest      119063.0
# 3046  0.050124     DC   Northest      121200.0
# 3047  0.049168     DC   Northest      122100.0
# 3048  0.047615     DC   Northest      123901.0
# 3049  0.044880     DC   Northest      125025.0
#
# [2950 rows x 22 columns]

# %%
# add the zori_index from the metros df to the homebuilding data. They will be merged on the date and name columns
homebuilding_2020 = homebuilding_2020.merge(metros[['name', 'date', 'zori_index']], on=['name', 'date'], how='left')

homebuilding_2020
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2020-01-01     Atlanta, GA  2912.0     2912.0       2932.0
# 1     2020-02-01     Atlanta, GA  2742.0     5661.0       2758.0
# 2     2020-03-01     Atlanta, GA  2216.0     7883.0       2227.0
# 3     2020-04-01     Atlanta, GA  1827.0     9633.0       1830.0
# 4     2020-05-01     Atlanta, GA  1970.0    11641.0       1982.0
# ...          ...             ...     ...        ...          ...
# 2945  2024-07-01  Washington, DC  1983.0    13587.0       2006.0
# 2946  2024-08-01  Washington, DC  2137.0    15660.0       2159.0
# 2947  2024-09-01  Washington, DC   900.0    16477.0        910.0
# 2948  2024-10-01  Washington, DC  1801.0    19004.0       1813.0
# 2949  2024-11-01  Washington, DC  1124.0    20058.0       1135.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0              2932.0   7119.0    7161.0  1373.374324  33.7628  ...
# 1              5694.0   9861.0    9919.0  1378.194661  33.7628  ...
# 2              7929.0  12077.0   12146.0  1386.720356  33.7628  ...
# 3              9675.0  13904.0   13976.0  1394.803270  33.7628  ...
# 4             11696.0  15874.0   15958.0  1397.741606  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 2945          13728.0  22572.0   22822.0  2365.897539  38.9047  ...
# 2946          15822.0  22460.0   22694.0  2381.806738  38.9047  ...
# 2947          16648.0  21885.0   22115.0  2390.051806  38.9047  ...
# 2948          19185.0  21838.0   22060.0  2389.848641  38.9047  ...
# 2949          20249.0  21457.0   21670.0  2379.846903  38.9047  ...
#
#       total_ytd_pc  multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  \
# 0         0.461690        0.464861            0.464861  1.128699     1.135358
# 1         0.897537        0.437274            0.902769  1.563436     1.572632
# 2         1.249829        0.353085            1.257123  1.914777     1.925717
# 3         1.527287        0.290142            1.533946  2.204443     2.215859
# 4         1.845651        0.314241            1.854371  2.516782     2.530100
# ...            ...             ...                 ...       ...          ...
# 2945      2.154965        0.318161            2.177328  3.580030     3.619681
# 2946      2.483753        0.342428            2.509447  3.562266     3.599380
# 2947      2.613333        0.144330            2.640455  3.471068     3.507548
# 2948      3.014128        0.287551            3.042835  3.463614     3.498824
# 2949      3.181297        0.180017            3.211591  3.403186     3.436968
#
#       zori_yoy  state     region  running_total  zori_index
# 0          NaN     GA  Southeast         2912.0  100.000000
# 1          NaN     GA  Southeast         5654.0  100.350985
# 2          NaN     GA  Southeast         7870.0  100.971769
# 3          NaN     GA  Southeast         9697.0  101.560314
# 4          NaN     GA  Southeast        11667.0  101.774264
# ...        ...    ...        ...            ...         ...
# 2945  0.050730     DC   Northest       119063.0  123.182070
# 2946  0.050124     DC   Northest       121200.0  124.010393
# 2947  0.049168     DC   Northest       122100.0  124.439678
# 2948  0.047615     DC   Northest       123901.0  124.429100
# 2949  0.044880     DC   Northest       125025.0  123.908353
#
# [2950 rows x 23 columns]

# %%
# create running total per 10k people (pop_2023 is population)
homebuilding_2020['running_total_per_10k'] = (homebuilding_2020['running_total'] / homebuilding_2020['pop_2023']) * 10000

homebuilding_2020
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2020-01-01     Atlanta, GA  2912.0     2912.0       2932.0
# 1     2020-02-01     Atlanta, GA  2742.0     5661.0       2758.0
# 2     2020-03-01     Atlanta, GA  2216.0     7883.0       2227.0
# 3     2020-04-01     Atlanta, GA  1827.0     9633.0       1830.0
# 4     2020-05-01     Atlanta, GA  1970.0    11641.0       1982.0
# ...          ...             ...     ...        ...          ...
# 2945  2024-07-01  Washington, DC  1983.0    13587.0       2006.0
# 2946  2024-08-01  Washington, DC  2137.0    15660.0       2159.0
# 2947  2024-09-01  Washington, DC   900.0    16477.0        910.0
# 2948  2024-10-01  Washington, DC  1801.0    19004.0       1813.0
# 2949  2024-11-01  Washington, DC  1124.0    20058.0       1135.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0              2932.0   7119.0    7161.0  1373.374324  33.7628  ...
# 1              5694.0   9861.0    9919.0  1378.194661  33.7628  ...
# 2              7929.0  12077.0   12146.0  1386.720356  33.7628  ...
# 3              9675.0  13904.0   13976.0  1394.803270  33.7628  ...
# 4             11696.0  15874.0   15958.0  1397.741606  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 2945          13728.0  22572.0   22822.0  2365.897539  38.9047  ...
# 2946          15822.0  22460.0   22694.0  2381.806738  38.9047  ...
# 2947          16648.0  21885.0   22115.0  2390.051806  38.9047  ...
# 2948          19185.0  21838.0   22060.0  2389.848641  38.9047  ...
# 2949          20249.0  21457.0   21670.0  2379.846903  38.9047  ...
#
#       multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  zori_yoy  \
# 0           0.464861            0.464861  1.128699     1.135358       NaN
# 1           0.437274            0.902769  1.563436     1.572632       NaN
# 2           0.353085            1.257123  1.914777     1.925717       NaN
# 3           0.290142            1.533946  2.204443     2.215859       NaN
# 4           0.314241            1.854371  2.516782     2.530100       NaN
# ...              ...                 ...       ...          ...       ...
# 2945        0.318161            2.177328  3.580030     3.619681  0.050730
# 2946        0.342428            2.509447  3.562266     3.599380  0.050124
# 2947        0.144330            2.640455  3.471068     3.507548  0.049168
# 2948        0.287551            3.042835  3.463614     3.498824  0.047615
# 2949        0.180017            3.211591  3.403186     3.436968  0.044880
#
#       state     region  running_total  zori_index running_total_per_10k
# 0        GA  Southeast         2912.0  100.000000              4.616901
# 1        GA  Southeast         5654.0  100.350985              8.964271
# 2        GA  Southeast         7870.0  100.971769             12.477682
# 3        GA  Southeast         9697.0  101.560314             15.374344
# 4        GA  Southeast        11667.0  101.774264             18.497728
# ...     ...        ...            ...         ...                   ...
# 2945     DC   Northest       119063.0  123.182070            188.839765
# 2946     DC   Northest       121200.0  124.010393            192.229152
# 2947     DC   Northest       122100.0  124.439678            193.656597
# 2948     DC   Northest       123901.0  124.429100            196.513071
# 2949     DC   Northest       125025.0  123.908353            198.295790
#
# [2950 rows x 24 columns]

# %%
homebuilding_2020.to_csv('data/homebuilding_zori_indexed.csv', index=False)

# %%
# show only indianapolis
homebuilding_2020[homebuilding_2020['name'] == 'Indianapolis, IN']
realtor_data = pd.read_csv(realtor_url)

realtor_data
# Out:
#        month_date_yyyymm  cbsa_code                             cbsa_title  \
# 0                 202412      35620  New York-Newark-Jersey City, NY-NJ-PA
# 1                 202412      31080     Los Angeles-Long Beach-Anaheim, CA
# 2                 202412      16980     Chicago-Naperville-Elgin, IL-IN-WI
# 3                 202412      19100        Dallas-Fort Worth-Arlington, TX
# 4                 202412      26420   Houston-The Woodlands-Sugar Land, TX
# ...                  ...        ...                                    ...
# 94549             201607      18780                              Craig, CO
# 94550             201607      46900                             Vernon, TX
# 94551             201607      49820                             Zapata, TX
# 94552             201607      37780                              Pecos, TX
# 94553             201607      29500                             Lamesa, TX
#
#        HouseholdRank  median_listing_price  median_listing_price_mm  \
# 0                  1                749000                  -0.0013
# 1                  2               1094000                  -0.0319
# 2                  3                347450                  -0.0346
# 3                  4                422450                  -0.0130
# 4                  5                361405                  -0.0098
# ...              ...                   ...                      ...
# 94549            923                174900                      NaN
# 94550            924                139000                      NaN
# 94551            925                104000                      NaN
# 94552            926                117700                      NaN
# 94553            927                118450                      NaN
#
#        median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                       0.0202                 29297                  -0.1344
# 1                      -0.0055                 12686                  -0.1700
# 2                      -0.0073                 14155                  -0.1598
# 3                      -0.0289                 22744                  -0.1079
# 4                       0.0039                 26614                  -0.0360
# ...                        ...                   ...                      ...
# 94549                      NaN                   173                      NaN
# 94550                      NaN                     3                      NaN
# 94551                      NaN                    27                      NaN
# 94552                      NaN                     5                      NaN
# 94553                      NaN                    12                      NaN
#
#        active_listing_count_yy  ...  average_listing_price  \
# 0                       0.0028  ...                1648167
# 1                       0.2630  ...                2398115
# 2                       0.0636  ...                 515696
# 3                       0.3111  ...                 600314
# 4                       0.2450  ...                 487031
# ...                        ...  ...                    ...
# 94549                      NaN  ...                 204604
# 94550                      NaN  ...                 172800
# 94551                      NaN  ...                 121803
# 94552                      NaN  ...                 101975
# 94553                      NaN  ...                 133733
#
#        average_listing_price_mm  average_listing_price_yy  \
# 0                        0.0067                   -0.0630
# 1                        0.0180                   -0.0783
# 2                       -0.0257                   -0.0355
# 3                       -0.0159                   -0.0448
# 4                       -0.0129                   -0.0344
# ...                         ...                       ...
# 94549                       NaN                       NaN
# 94550                       NaN                       NaN
# 94551                       NaN                       NaN
# 94552                       NaN                       NaN
# 94553                       NaN                       NaN
#
#        total_listing_count  total_listing_count_mm  total_listing_count_yy  \
# 0                    50240                 -0.0274                  0.1692
# 1                    18822                 -0.1603                  0.1937
# 2                    22540                 -0.1740                  0.0425
# 3                    30828                 -0.1221                  0.2187
# 4                    35275                 -0.0490                  0.1991
# ...                    ...                     ...                     ...
# 94549                  195                     NaN                     NaN
# 94550                    5                     NaN                     NaN
# 94551                   27                     NaN                     NaN
# 94552                    5                     NaN                     NaN
# 94553                   14                     NaN                     NaN
#
#        pending_ratio  pending_ratio_mm  pending_ratio_yy  quality_flag
# 0             0.7317            0.1921            0.2503           0.0
# 1             0.4864            0.0222           -0.0788           0.0
# 2             0.5951           -0.0286           -0.0320           0.0
# 3             0.3557           -0.0229           -0.0994           0.0
# 4             0.3262           -0.0203           -0.0492           0.0
# ...              ...               ...               ...           ...
# 94549         0.1272               NaN               NaN           NaN
# 94550         0.6667               NaN               NaN           NaN
# 94551            NaN               NaN               NaN           NaN
# 94552            NaN               NaN               NaN           NaN
# 94553         0.1667               NaN               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
# Extract the first part of the cbsa_title before the first hyphen and the first state abbreviation
realtor_data['cbsa_title'] = realtor_data['cbsa_title'].str.replace(r'^(.*?)-.*?,\s(\w{2}).*$', r'\1, \2')

realtor_data
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gn/T/ipykernel_60425/900176153.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   realtor_data['cbsa_title'] = realtor_data['cbsa_title'].str.replace(r'^(.*?)-.*?,\s(\w{2}).*$', r'\1, \2')
#        month_date_yyyymm  cbsa_code       cbsa_title  HouseholdRank  \
# 0                 202412      35620     New York, NY              1
# 1                 202412      31080  Los Angeles, CA              2
# 2                 202412      16980      Chicago, IL              3
# 3                 202412      19100       Dallas, TX              4
# 4                 202412      26420      Houston, TX              5
# ...                  ...        ...              ...            ...
# 94549             201607      18780        Craig, CO            923
# 94550             201607      46900       Vernon, TX            924
# 94551             201607      49820       Zapata, TX            925
# 94552             201607      37780        Pecos, TX            926
# 94553             201607      29500       Lamesa, TX            927
#
#        median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0                    749000                  -0.0013                   0.0202
# 1                   1094000                  -0.0319                  -0.0055
# 2                    347450                  -0.0346                  -0.0073
# 3                    422450                  -0.0130                  -0.0289
# 4                    361405                  -0.0098                   0.0039
# ...                     ...                      ...                      ...
# 94549                174900                      NaN                      NaN
# 94550                139000                      NaN                      NaN
# 94551                104000                      NaN                      NaN
# 94552                117700                      NaN                      NaN
# 94553                118450                      NaN                      NaN
#
#        active_listing_count  active_listing_count_mm  active_listing_count_yy  \
# 0                     29297                  -0.1344                   0.0028
# 1                     12686                  -0.1700                   0.2630
# 2                     14155                  -0.1598                   0.0636
# 3                     22744                  -0.1079                   0.3111
# 4                     26614                  -0.0360                   0.2450
# ...                     ...                      ...                      ...
# 94549                   173                      NaN                      NaN
# 94550                     3                      NaN                      NaN
# 94551                    27                      NaN                      NaN
# 94552                     5                      NaN                      NaN
# 94553                    12                      NaN                      NaN
#
#        ...  average_listing_price  average_listing_price_mm  \
# 0      ...                1648167                    0.0067
# 1      ...                2398115                    0.0180
# 2      ...                 515696                   -0.0257
# 3      ...                 600314                   -0.0159
# 4      ...                 487031                   -0.0129
# ...    ...                    ...                       ...
# 94549  ...                 204604                       NaN
# 94550  ...                 172800                       NaN
# 94551  ...                 121803                       NaN
# 94552  ...                 101975                       NaN
# 94553  ...                 133733                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       -0.0630                50240                 -0.0274
# 1                       -0.0783                18822                 -0.1603
# 2                       -0.0355                22540                 -0.1740
# 3                       -0.0448                30828                 -0.1221
# 4                       -0.0344                35275                 -0.0490
# ...                         ...                  ...                     ...
# 94549                       NaN                  195                     NaN
# 94550                       NaN                    5                     NaN
# 94551                       NaN                   27                     NaN
# 94552                       NaN                    5                     NaN
# 94553                       NaN                   14                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                      0.1692         0.7317            0.1921
# 1                      0.1937         0.4864            0.0222
# 2                      0.0425         0.5951           -0.0286
# 3                      0.2187         0.3557           -0.0229
# 4                      0.1991         0.3262           -0.0203
# ...                       ...            ...               ...
# 94549                     NaN         0.1272               NaN
# 94550                     NaN         0.6667               NaN
# 94551                     NaN            NaN               NaN
# 94552                     NaN            NaN               NaN
# 94553                     NaN         0.1667               NaN
#
#        pending_ratio_yy  quality_flag
# 0                0.2503           0.0
# 1               -0.0788           0.0
# 2               -0.0320           0.0
# 3               -0.0994           0.0
# 4               -0.0492           0.0
# ...                 ...           ...
# 94549               NaN           NaN
# 94550               NaN           NaN
# 94551               NaN           NaN
# 94552               NaN           NaN
# 94553               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
# convert 'month_date_yyyymm' to datetime
realtor_data['month_date_yyyymm'] = pd.to_datetime(realtor_data['month_date_yyyymm'], format='%Y%m')

realtor_data
# Out:
#       month_date_yyyymm  cbsa_code       cbsa_title  HouseholdRank  \
# 0            2024-12-01      35620     New York, NY              1
# 1            2024-12-01      31080  Los Angeles, CA              2
# 2            2024-12-01      16980      Chicago, IL              3
# 3            2024-12-01      19100       Dallas, TX              4
# 4            2024-12-01      26420      Houston, TX              5
# ...                 ...        ...              ...            ...
# 94549        2016-07-01      18780        Craig, CO            923
# 94550        2016-07-01      46900       Vernon, TX            924
# 94551        2016-07-01      49820       Zapata, TX            925
# 94552        2016-07-01      37780        Pecos, TX            926
# 94553        2016-07-01      29500       Lamesa, TX            927
#
#        median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0                    749000                  -0.0013                   0.0202
# 1                   1094000                  -0.0319                  -0.0055
# 2                    347450                  -0.0346                  -0.0073
# 3                    422450                  -0.0130                  -0.0289
# 4                    361405                  -0.0098                   0.0039
# ...                     ...                      ...                      ...
# 94549                174900                      NaN                      NaN
# 94550                139000                      NaN                      NaN
# 94551                104000                      NaN                      NaN
# 94552                117700                      NaN                      NaN
# 94553                118450                      NaN                      NaN
#
#        active_listing_count  active_listing_count_mm  active_listing_count_yy  \
# 0                     29297                  -0.1344                   0.0028
# 1                     12686                  -0.1700                   0.2630
# 2                     14155                  -0.1598                   0.0636
# 3                     22744                  -0.1079                   0.3111
# 4                     26614                  -0.0360                   0.2450
# ...                     ...                      ...                      ...
# 94549                   173                      NaN                      NaN
# 94550                     3                      NaN                      NaN
# 94551                    27                      NaN                      NaN
# 94552                     5                      NaN                      NaN
# 94553                    12                      NaN                      NaN
#
#        ...  average_listing_price  average_listing_price_mm  \
# 0      ...                1648167                    0.0067
# 1      ...                2398115                    0.0180
# 2      ...                 515696                   -0.0257
# 3      ...                 600314                   -0.0159
# 4      ...                 487031                   -0.0129
# ...    ...                    ...                       ...
# 94549  ...                 204604                       NaN
# 94550  ...                 172800                       NaN
# 94551  ...                 121803                       NaN
# 94552  ...                 101975                       NaN
# 94553  ...                 133733                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       -0.0630                50240                 -0.0274
# 1                       -0.0783                18822                 -0.1603
# 2                       -0.0355                22540                 -0.1740
# 3                       -0.0448                30828                 -0.1221
# 4                       -0.0344                35275                 -0.0490
# ...                         ...                  ...                     ...
# 94549                       NaN                  195                     NaN
# 94550                       NaN                    5                     NaN
# 94551                       NaN                   27                     NaN
# 94552                       NaN                    5                     NaN
# 94553                       NaN                   14                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                      0.1692         0.7317            0.1921
# 1                      0.1937         0.4864            0.0222
# 2                      0.0425         0.5951           -0.0286
# 3                      0.2187         0.3557           -0.0229
# 4                      0.1991         0.3262           -0.0203
# ...                       ...            ...               ...
# 94549                     NaN         0.1272               NaN
# 94550                     NaN         0.6667               NaN
# 94551                     NaN            NaN               NaN
# 94552                     NaN            NaN               NaN
# 94553                     NaN         0.1667               NaN
#
#        pending_ratio_yy  quality_flag
# 0                0.2503           0.0
# 1               -0.0788           0.0
# 2               -0.0320           0.0
# 3               -0.0994           0.0
# 4               -0.0492           0.0
# ...                 ...           ...
# 94549               NaN           NaN
# 94550               NaN           NaN
# 94551               NaN           NaN
# 94552               NaN           NaN
# 94553               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
realtor_data.columns
# Out:
# Index(['month_date_yyyymm', 'cbsa_code', 'cbsa_title', 'HouseholdRank',
#        'median_listing_price', 'median_listing_price_mm',
#        'median_listing_price_yy', 'active_listing_count',
#        'active_listing_count_mm', 'active_listing_count_yy',
#        'median_days_on_market', 'median_days_on_market_mm',
#        'median_days_on_market_yy', 'new_listing_count', 'new_listing_count_mm',
#        'new_listing_count_yy', 'price_increased_count',
#        'price_increased_count_mm', 'price_increased_count_yy',
#        'price_reduced_count', 'price_reduced_count_mm',
#        'price_reduced_count_yy', 'pending_listing_count',
#        'pending_listing_count_mm', 'pending_listing_count_yy',
#        'median_listing_price_per_square_foot',
#        'median_listing_price_per_square_foot_mm',
#        'median_listing_price_per_square_foot_yy', 'median_square_feet',
#        'median_square_feet_mm', 'median_square_feet_yy',
#        'average_listing_price', 'average_listing_price_mm',
#        'average_listing_price_yy', 'total_listing_count',
#        'total_listing_count_mm', 'total_listing_count_yy', 'pending_ratio',
#        'pending_ratio_mm', 'pending_ratio_yy', 'quality_flag'],
#       dtype='object')

# %%
realtor_data = realtor_data[['month_date_yyyymm','cbsa_code','cbsa_title', 'new_listing_count']]

realtor_data.columns = ['date', 'id', 'name', 'new_listings']

realtor_data
# Out:
#             date     id             name  new_listings
# 0     2024-12-01  35620     New York, NY          7948
# 1     2024-12-01  31080  Los Angeles, CA          4324
# 2     2024-12-01  16980      Chicago, IL          4936
# 3     2024-12-01  19100       Dallas, TX          6278
# 4     2024-12-01  26420      Houston, TX          7070
# ...          ...    ...              ...           ...
# 94549 2016-07-01  18780        Craig, CO            28
# 94550 2016-07-01  46900       Vernon, TX             0
# 94551 2016-07-01  49820       Zapata, TX             4
# 94552 2016-07-01  37780        Pecos, TX             0
# 94553 2016-07-01  29500       Lamesa, TX             0
#
# [94554 rows x 4 columns]

# %%
# import the top_metros data. It's a JSON with a list.
import json

with open('data/top_metros.json') as f:
    top_metros = json.load(f)

# restrict the realtor data to only the top metros
realtor_data = realtor_data[realtor_data['name'].isin(top_metros)]

realtor_data
# Out:
#             date     id                name  new_listings
# 0     2024-12-01  35620        New York, NY          7948
# 1     2024-12-01  31080     Los Angeles, CA          4324
# 2     2024-12-01  16980         Chicago, IL          4936
# 3     2024-12-01  19100          Dallas, TX          6278
# 4     2024-12-01  26420         Houston, TX          7070
# ...          ...    ...                 ...           ...
# 93673 2016-07-01  15380         Buffalo, NY          1248
# 93674 2016-07-01  25540        Hartford, CT          1956
# 93676 2016-07-01  13820      Birmingham, AL          1936
# 93678 2016-07-01  41620  Salt Lake City, UT          1984
# 93679 2016-07-01  24340    Grand Rapids, MI           428
#
# [4590 rows x 4 columns]

# %%
# convert metros.date to datetime
metros['date'] = pd.to_datetime(metros['date'])

metros.dtypes
# Out:
# name                  object
# date          datetime64[ns]
# zori                 float64
# lat                  float64
# lng                  float64
# pop_2023             float64
# state                 object
# region                object
# zori_index           float64
# dtype: object

# %%
# add the pop_2023 column to the realtor data. It will be merged on the name and date columns
realtor_data = realtor_data.merge(metros[['name', 'date', 'pop_2023']], on=['name', 'date'], how='left')

# %%
# sort by date, then name with earliest date first
realtor_data = realtor_data.sort_values(['date', 'name'])

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
# [4590 rows x 5 columns]

# %%
# Calculate the cumulative sum of new_listings for each id since the earliest date
realtor_data['cumulative_new_listings'] = realtor_data.groupby('id')['new_listings'].cumsum()

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings
# 4553                    11888
# 4570                     3668
# 4564                     5048
# 4587                     1936
# 4554                     6268
# ...                       ...
# 35                     130238
# 13                     495438
# 16                     617218
# 32                     279784
# 6                      839272
#
# [4590 rows x 6 columns]

# %%
# add a state column that extracts the state from the name column
realtor_data['state'] = realtor_data['name'].str.extract(r',\s(.*)$')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state
# 4553                    11888    GA
# 4570                     3668    TX
# 4564                     5048    MD
# 4587                     1936    AL
# 4554                     6268    MA
# ...                       ...   ...
# 35                     130238    CA
# 13                     495438    WA
# 16                     617218    FL
# 32                     279784    VA
# 6                      839272    DC
#
# [4590 rows x 7 columns]

# %%
# add region col
realtor_data = realtor_data.merge(regions, on='state', how='left')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region
# 0                       11888    GA  Southeast
# 1                        3668    TX  Southwest
# 2                        5048    MD   Northest
# 3                        1936    AL  Southeast
# 4                        6268    MA   Northest
# ...                       ...   ...        ...
# 4585                   130238    CA       West
# 4586                   495438    WA       West
# 4587                   617218    FL  Southeast
# 4588                   279784    VA  Southeast
# 4589                   839272    DC   Northest
#
# [4590 rows x 8 columns]

# %%
# add zori and zori_index from metros to realtor_data
realtor_data = realtor_data.merge(metros[['name', 'date', 'zori', 'zori_index']], on=['name', 'date'], how='left')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index
# 0                       11888    GA  Southeast  1133.885137   82.561987
# 1                        3668    TX  Southwest  1286.087094   90.271224
# 2                        5048    MD   Northest  1374.881054   94.719129
# 3                        1936    AL  Southeast   922.773482   90.478772
# 4                        6268    MA   Northest  2129.591065   91.341245
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  111.343869
# 4586                   495438    WA       West  2220.617862  124.087570
# 4587                   617218    FL  Southeast  2057.590695  152.851085
# 4588                   279784    VA  Southeast  1764.030482  142.402366
# 4589                   839272    DC   Northest  2372.478358  123.524705
#
# [4590 rows x 10 columns]

# %%
# make the zori_index an index of zori where july 2016 is 100
base_zori = metros[metros['date'] == '2016-07-01'].set_index('name')['zori']

realtor_data['zori_index'] = realtor_data.apply(lambda row: (row['zori'] / base_zori[row['name']]) * 100 if row['name'] in base_zori else None, axis=1)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
# [4590 rows x 10 columns]

# %%
# create a new_listings per 10k people column and cumulative_new_listings per 10k people column
realtor_data['new_per_10k'] = (realtor_data['new_listings'] / realtor_data['pop_2023']) * 10000

realtor_data['cumulative_per_10k'] = (realtor_data['cumulative_new_listings'] / realtor_data['pop_2023']) * 10000

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k
# 0       18.848118           18.848118
# 1       14.830538           14.830538
# 2       17.810294           17.810294
# 3       16.347347           16.347347
# 4       12.741964           12.741964
# ...           ...                 ...
# 4585     1.809055          669.340163
# 4586     3.975438         1224.865180
# 4587    13.802127         1846.320166
# 4588     7.900764         1565.515069
# 4589     5.490902         1331.126610
#
# [4590 rows x 12 columns]

# %%
# add a yoy change column for zori
realtor_data['zori_yoy'] = realtor_data.groupby('name')['zori'].pct_change(12)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy
# 0       18.848118           18.848118       NaN
# 1       14.830538           14.830538       NaN
# 2       17.810294           17.810294       NaN
# 3       16.347347           16.347347       NaN
# 4       12.741964           12.741964       NaN
# ...           ...                 ...       ...
# 4585     1.809055          669.340163  0.046295
# 4586     3.975438         1224.865180  0.038656
# 4587    13.802127         1846.320166  0.024556
# 4588     7.900764         1565.515069  0.050527
# 4589     5.490902         1331.126610  0.044968
#
# [4590 rows x 13 columns]

# %%
# create a new_listings_yoy column
realtor_data['new_listings_yoy'] = realtor_data.groupby('name')['new_listings'].pct_change(12)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy  new_listings_yoy
# 0       18.848118           18.848118       NaN               NaN
# 1       14.830538           14.830538       NaN               NaN
# 2       17.810294           17.810294       NaN               NaN
# 3       16.347347           16.347347       NaN               NaN
# 4       12.741964           12.741964       NaN               NaN
# ...           ...                 ...       ...               ...
# 4585     1.809055          669.340163  0.046295         -0.185185
# 4586     3.975438         1224.865180  0.038656         -0.073733
# 4587    13.802127         1846.320166  0.024556          0.080056
# 4588     7.900764         1565.515069  0.050527          0.168874
# 4589     5.490902         1331.126610  0.044968         -0.035117
#
# [4590 rows x 14 columns]

# %%
# Create a mask for dates since January 2020
mask = realtor_data['date'] >= '2020-01-01'

# Initialize the new column with NaN values
realtor_data['cumulative_since_2020'] = pd.NA

# Calculate the cumulative sum for dates since January 2020
realtor_data.loc[mask, 'cumulative_since_2020'] = realtor_data[mask].groupby('name')['new_listings'].cumsum()

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy  new_listings_yoy  \
# 0       18.848118           18.848118       NaN               NaN
# 1       14.830538           14.830538       NaN               NaN
# 2       17.810294           17.810294       NaN               NaN
# 3       16.347347           16.347347       NaN               NaN
# 4       12.741964           12.741964       NaN               NaN
# ...           ...                 ...       ...               ...
# 4585     1.809055          669.340163  0.046295         -0.185185
# 4586     3.975438         1224.865180  0.038656         -0.073733
# 4587    13.802127         1846.320166  0.024556          0.080056
# 4588     7.900764         1565.515069  0.050527          0.168874
# 4589     5.490902         1331.126610  0.044968         -0.035117
#
#      cumulative_since_2020
# 0                     <NA>
# 1                     <NA>
# 2                     <NA>
# 3                     <NA>
# 4                     <NA>
# ...                    ...
# 4585                 75106
# 4586                258246
# 4587                349814
# 4588                153312
# 4589                462458
#
# [4590 rows x 15 columns]

# %%
# make it numeric, coerce errors to NaN
realtor_data['cumulative_since_2020'] = pd.to_numeric(realtor_data['cumulative_since_2020'], errors='coerce')

realtor_data.dtypes
# Out:
# date                       datetime64[ns]
# id                                  int64
# name                               object
# new_listings                        int64
# pop_2023                          float64
# cumulative_new_listings             int64
# state                              object
# region                             object
# zori                              float64
# zori_index                        float64
# new_per_10k                       float64
# cumulative_per_10k                float64
# zori_yoy                          float64
# new_listings_yoy                  float64
# cumulative_since_2020             float64
# dtype: object

# %%
# make it per 10k people
realtor_data['cumulative_since_2020'] = (realtor_data['cumulative_since_2020'] / realtor_data['pop_2023']) * 10000

# %%
realtor_data.to_csv('data/realtor_zori_indexed.csv', index=False)
