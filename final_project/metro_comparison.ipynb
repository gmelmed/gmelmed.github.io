# %%
import pandas as pd

# %%
metros = pd.read_csv('data/zori_metro_long_clean.csv')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2225.296911  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1802.281380  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1352.236287  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1082.375956  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1221.669822  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5995  Salt Lake City, UT  2025-01-01  1656.973108  40.7776 -111.9311
# 5996        Hartford, CT  2025-01-01  1870.252402  41.7661  -72.6834
# 5997         Buffalo, NY  2025-01-01  1324.995704  42.9018  -78.8487
# 5998      Birmingham, AL  2025-01-01  1339.420553  33.5279  -86.7971
# 5999    Grand Rapids, MI  2025-01-01  1742.311646  42.9619  -85.6562
#
#         pop_2023
# 0     19498249.0
# 1     12799100.0
# 2      9262825.0
# 3      8100037.0
# 4      7510253.0
# ...          ...
# 5995   1267864.0
# 5996   1151543.0
# 5997   1155604.0
# 5998   1184290.0
# 5999   1162950.0
#
# [6000 rows x 6 columns]

# %%
# get state name col from `name` col with everything after the last comma and space
metros['state'] = metros['name'].str.extract(r',\s(.*)$')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2225.296911  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1802.281380  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1352.236287  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1082.375956  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1221.669822  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5995  Salt Lake City, UT  2025-01-01  1656.973108  40.7776 -111.9311
# 5996        Hartford, CT  2025-01-01  1870.252402  41.7661  -72.6834
# 5997         Buffalo, NY  2025-01-01  1324.995704  42.9018  -78.8487
# 5998      Birmingham, AL  2025-01-01  1339.420553  33.5279  -86.7971
# 5999    Grand Rapids, MI  2025-01-01  1742.311646  42.9619  -85.6562
#
#         pop_2023 state
# 0     19498249.0    NY
# 1     12799100.0    CA
# 2      9262825.0    IL
# 3      8100037.0    TX
# 4      7510253.0    TX
# ...          ...   ...
# 5995   1267864.0    UT
# 5996   1151543.0    CT
# 5997   1155604.0    NY
# 5998   1184290.0    AL
# 5999   1162950.0    MI
#
# [6000 rows x 7 columns]

# %%
# import regions df
regions = pd.read_csv('data/regions.csv')

# %%
# merge metros and regions on state
metros = metros.merge(regions, on='state', how='left')

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2225.296911  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1802.281380  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1352.236287  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1082.375956  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1221.669822  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5995  Salt Lake City, UT  2025-01-01  1656.973108  40.7776 -111.9311
# 5996        Hartford, CT  2025-01-01  1870.252402  41.7661  -72.6834
# 5997         Buffalo, NY  2025-01-01  1324.995704  42.9018  -78.8487
# 5998      Birmingham, AL  2025-01-01  1339.420553  33.5279  -86.7971
# 5999    Grand Rapids, MI  2025-01-01  1742.311646  42.9619  -85.6562
#
#         pop_2023 state     region
# 0     19498249.0    NY   Northest
# 1     12799100.0    CA       West
# 2      9262825.0    IL    Midwest
# 3      8100037.0    TX  Southwest
# 4      7510253.0    TX  Southwest
# ...          ...   ...        ...
# 5995   1267864.0    UT       West
# 5996   1151543.0    CT   Northest
# 5997   1155604.0    NY   Northest
# 5998   1184290.0    AL  Southeast
# 5999   1162950.0    MI    Midwest
#
# [6000 rows x 8 columns]

# %%
# Set the base zori value for each name in January 2016 to 100
base_zori = metros[metros['date'] == '2020-01-01'].set_index('name')['zori']

# Calculate the zori_index
metros['zori_index'] = metros.apply(lambda row: (row['zori'] / base_zori[row['name']]) * 100 if row['name'] in base_zori else None, axis=1)

metros
# Out:
#                     name        date         zori      lat       lng  \
# 0           New York, NY  2015-02-01  2225.296911  40.6943  -73.9249
# 1        Los Angeles, CA  2015-02-01  1802.281380  34.1141 -118.4068
# 2            Chicago, IL  2015-02-01  1352.236287  41.8375  -87.6866
# 3             Dallas, TX  2015-02-01  1082.375956  32.7935  -96.7667
# 4            Houston, TX  2015-02-01  1221.669822  29.7860  -95.3885
# ...                  ...         ...          ...      ...       ...
# 5995  Salt Lake City, UT  2025-01-01  1656.973108  40.7776 -111.9311
# 5996        Hartford, CT  2025-01-01  1870.252402  41.7661  -72.6834
# 5997         Buffalo, NY  2025-01-01  1324.995704  42.9018  -78.8487
# 5998      Birmingham, AL  2025-01-01  1339.420553  33.5279  -86.7971
# 5999    Grand Rapids, MI  2025-01-01  1742.311646  42.9619  -85.6562
#
#         pop_2023 state     region  zori_index
# 0     19498249.0    NY   Northest   88.222667
# 1     12799100.0    CA       West   77.652685
# 2      9262825.0    IL    Midwest   88.214033
# 3      8100037.0    TX  Southwest   81.140737
# 4      7510253.0    TX  Southwest   89.894512
# ...          ...   ...        ...         ...
# 5995   1267864.0    UT       West  133.736424
# 5996   1151543.0    CT   Northest  145.947202
# 5997   1155604.0    NY   Northest  141.356459
# 5998   1184290.0    AL  Southeast  133.503793
# 5999   1162950.0    MI    Midwest  141.707362
#
# [6000 rows x 9 columns]

# %%
# in name, remove the state name and the last comma and space
metros['name'] = metros['name'].str.replace(r',\s.*$', '', regex=True)

metros
# Out:
#                 name        date         zori      lat       lng    pop_2023  \
# 0           New York  2015-02-01  2225.296911  40.6943  -73.9249  19498249.0
# 1        Los Angeles  2015-02-01  1802.281380  34.1141 -118.4068  12799100.0
# 2            Chicago  2015-02-01  1352.236287  41.8375  -87.6866   9262825.0
# 3             Dallas  2015-02-01  1082.375956  32.7935  -96.7667   8100037.0
# 4            Houston  2015-02-01  1221.669822  29.7860  -95.3885   7510253.0
# ...              ...         ...          ...      ...       ...         ...
# 5995  Salt Lake City  2025-01-01  1656.973108  40.7776 -111.9311   1267864.0
# 5996        Hartford  2025-01-01  1870.252402  41.7661  -72.6834   1151543.0
# 5997         Buffalo  2025-01-01  1324.995704  42.9018  -78.8487   1155604.0
# 5998      Birmingham  2025-01-01  1339.420553  33.5279  -86.7971   1184290.0
# 5999    Grand Rapids  2025-01-01  1742.311646  42.9619  -85.6562   1162950.0
#
#      state     region  zori_index
# 0       NY   Northest   88.222667
# 1       CA       West   77.652685
# 2       IL    Midwest   88.214033
# 3       TX  Southwest   81.140737
# 4       TX  Southwest   89.894512
# ...    ...        ...         ...
# 5995    UT       West  133.736424
# 5996    CT   Northest  145.947202
# 5997    NY   Northest  141.356459
# 5998    AL  Southeast  133.503793
# 5999    MI    Midwest  141.707362
#
# [6000 rows x 9 columns]

# %%
metros.to_csv('data/zori_metro_indexed_long.csv', index=False)

# %%
# import the homebuilding data
homebuilding = pd.read_csv('data/homebuilding_zori.csv')

homebuilding
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2019-11-01     Atlanta, GA  1819.0    30513.0        117.0
# 1     2019-12-01     Atlanta, GA  2388.0    32729.0        213.0
# 2     2020-01-01     Atlanta, GA  2912.0     2912.0        973.0
# 3     2020-02-01     Atlanta, GA  2742.0     5661.0        651.0
# 4     2020-03-01     Atlanta, GA  2216.0     7883.0        127.0
# ...          ...             ...     ...        ...          ...
# 3095  2024-08-01  Washington, DC  2137.0    15660.0       1257.0
# 3096  2024-09-01  Washington, DC   900.0    16477.0        222.0
# 3097  2024-10-01  Washington, DC  1801.0    19004.0        922.0
# 3098  2024-11-01  Washington, DC  1124.0    20058.0        318.0
# 3099  2024-12-01  Washington, DC  1506.0    21931.0        772.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0              6602.0   1819.0     117.0  1371.279930  33.7628  ...
# 1              6732.0   4207.0     330.0  1368.872179  33.7628  ...
# 2               973.0   7119.0    1303.0  1368.798323  33.7628  ...
# 3              1562.0   9861.0    1954.0  1373.768759  33.7628  ...
# 4              1633.0  12077.0    2081.0  1382.102627  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 3095           7569.0  22460.0   11575.0  2375.472810  38.9047  ...
# 3096           7747.0  21885.0   11089.0  2383.224478  38.9047  ...
# 3097           8651.0  21838.0   10897.0  2382.780218  38.9047  ...
# 3098           8903.0  21457.0   10369.0  2372.798426  38.9047  ...
# 3099           9983.0  21188.0   10023.0  2365.752183  38.9047  ...
#
#        pop_2023  total_pc  total_ytd_pc  multi_total_pc  multi_total_ytd_pc  \
# 0     6307261.0  0.288398      4.837758        0.018550            1.046730
# 1     6307261.0  0.378611      5.189099        0.033771            1.067341
# 2     6307261.0  0.461690      0.461690        0.154267            0.154267
# 3     6307261.0  0.434737      0.897537        0.103214            0.247651
# 4     6307261.0  0.351341      1.249829        0.020136            0.258908
# ...         ...       ...           ...             ...                 ...
# 3095  6304975.0  0.338939      2.483753        0.199366            1.200481
# 3096  6304975.0  0.142744      2.613333        0.035210            1.228712
# 3097  6304975.0  0.285647      3.014128        0.146234            1.372091
# 3098  6304975.0  0.178272      3.181297        0.050436            1.412060
# 3099  6304975.0  0.238859      3.478364        0.122443            1.583353
#
#          rt_pc  multi_rt_pc  zori_yoy  state     region
# 0     0.288398     0.018550       NaN     GA  Southeast
# 1     0.667009     0.052321       NaN     GA  Southeast
# 2     1.128699     0.206587       NaN     GA  Southeast
# 3     1.563436     0.309802       NaN     GA  Southeast
# 4     1.914777     0.329937       NaN     GA  Southeast
# ...        ...          ...       ...    ...        ...
# 3095  3.562266     1.835852  0.050066     DC   Northest
# 3096  3.471068     1.758770  0.048862     DC   Northest
# 3097  3.463614     1.728318  0.047143     DC   Northest
# 3098  3.403186     1.644574  0.044723     DC   Northest
# 3099  3.360521     1.589697  0.045161     DC   Northest
#
# [3100 rows x 21 columns]

# %%
# Pivot the homebuilding dataframe to have dates as rows and metro areas as columns
pivot_homebuilding = homebuilding.pivot(index='date', columns='name', values='total')

# Find the earliest date where all values are non-null
earliest_date = pivot_homebuilding.dropna().index.min()

print(earliest_date)
# Out:
# 2019-11-01

# %%
# Filter the data to include only records from 2020 onwards
homebuilding_2020 = homebuilding[homebuilding['date'] >= '2020-01-01']

# Calculate the running total for each metro area
homebuilding_2020['running_total'] = homebuilding_2020.groupby('name')['multi_total'].cumsum()

homebuilding_2020
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gn/T/ipykernel_61236/2438567579.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   homebuilding_2020['running_total'] = homebuilding_2020.groupby('name')['multi_total'].cumsum()
#             date            name   total  total_ytd  multi_total  \
# 2     2020-01-01     Atlanta, GA  2912.0     2912.0        973.0
# 3     2020-02-01     Atlanta, GA  2742.0     5661.0        651.0
# 4     2020-03-01     Atlanta, GA  2216.0     7883.0        127.0
# 5     2020-04-01     Atlanta, GA  1827.0     9633.0        108.0
# 6     2020-05-01     Atlanta, GA  1970.0    11641.0        354.0
# ...          ...             ...     ...        ...          ...
# 3095  2024-08-01  Washington, DC  2137.0    15660.0       1257.0
# 3096  2024-09-01  Washington, DC   900.0    16477.0        222.0
# 3097  2024-10-01  Washington, DC  1801.0    19004.0        922.0
# 3098  2024-11-01  Washington, DC  1124.0    20058.0        318.0
# 3099  2024-12-01  Washington, DC  1506.0    21931.0        772.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  total_pc  \
# 2               973.0   7119.0    1303.0  1368.798323  33.7628  ...  0.461690
# 3              1562.0   9861.0    1954.0  1373.768759  33.7628  ...  0.434737
# 4              1633.0  12077.0    2081.0  1382.102627  33.7628  ...  0.351341
# 5              1648.0  13904.0    2189.0  1390.457345  33.7628  ...  0.289666
# 6              1922.0  15874.0    2543.0  1393.296553  33.7628  ...  0.312338
# ...               ...      ...       ...          ...      ...  ...       ...
# 3095           7569.0  22460.0   11575.0  2375.472810  38.9047  ...  0.338939
# 3096           7747.0  21885.0   11089.0  2383.224478  38.9047  ...  0.142744
# 3097           8651.0  21838.0   10897.0  2382.780218  38.9047  ...  0.285647
# 3098           8903.0  21457.0   10369.0  2372.798426  38.9047  ...  0.178272
# 3099           9983.0  21188.0   10023.0  2365.752183  38.9047  ...  0.238859
#
#       total_ytd_pc  multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  \
# 2         0.461690        0.154267            0.154267  1.128699     0.206587
# 3         0.897537        0.103214            0.247651  1.563436     0.309802
# 4         1.249829        0.020136            0.258908  1.914777     0.329937
# 5         1.527287        0.017123            0.261286  2.204443     0.347060
# 6         1.845651        0.056126            0.304728  2.516782     0.403186
# ...            ...             ...                 ...       ...          ...
# 3095      2.483753        0.199366            1.200481  3.562266     1.835852
# 3096      2.613333        0.035210            1.228712  3.471068     1.758770
# 3097      3.014128        0.146234            1.372091  3.463614     1.728318
# 3098      3.181297        0.050436            1.412060  3.403186     1.644574
# 3099      3.478364        0.122443            1.583353  3.360521     1.589697
#
#       zori_yoy  state     region running_total
# 2          NaN     GA  Southeast         973.0
# 3          NaN     GA  Southeast        1624.0
# 4          NaN     GA  Southeast        1751.0
# 5          NaN     GA  Southeast        1859.0
# 6          NaN     GA  Southeast        2213.0
# ...        ...    ...        ...           ...
# 3095  0.050066     DC   Northest       66429.0
# 3096  0.048862     DC   Northest       66651.0
# 3097  0.047143     DC   Northest       67573.0
# 3098  0.044723     DC   Northest       67891.0
# 3099  0.045161     DC   Northest       68663.0
#
# [3000 rows x 22 columns]

# %%
# add the zori_index from the metros df to the homebuilding data. They will be merged on the date and name columns
homebuilding_2020 = homebuilding_2020.merge(metros[['name', 'date', 'zori_index']], on=['name', 'date'], how='left')

homebuilding_2020
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2020-01-01     Atlanta, GA  2912.0     2912.0        973.0
# 1     2020-02-01     Atlanta, GA  2742.0     5661.0        651.0
# 2     2020-03-01     Atlanta, GA  2216.0     7883.0        127.0
# 3     2020-04-01     Atlanta, GA  1827.0     9633.0        108.0
# 4     2020-05-01     Atlanta, GA  1970.0    11641.0        354.0
# ...          ...             ...     ...        ...          ...
# 2995  2024-08-01  Washington, DC  2137.0    15660.0       1257.0
# 2996  2024-09-01  Washington, DC   900.0    16477.0        222.0
# 2997  2024-10-01  Washington, DC  1801.0    19004.0        922.0
# 2998  2024-11-01  Washington, DC  1124.0    20058.0        318.0
# 2999  2024-12-01  Washington, DC  1506.0    21931.0        772.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0               973.0   7119.0    1303.0  1368.798323  33.7628  ...
# 1              1562.0   9861.0    1954.0  1373.768759  33.7628  ...
# 2              1633.0  12077.0    2081.0  1382.102627  33.7628  ...
# 3              1648.0  13904.0    2189.0  1390.457345  33.7628  ...
# 4              1922.0  15874.0    2543.0  1393.296553  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 2995           7569.0  22460.0   11575.0  2375.472810  38.9047  ...
# 2996           7747.0  21885.0   11089.0  2383.224478  38.9047  ...
# 2997           8651.0  21838.0   10897.0  2382.780218  38.9047  ...
# 2998           8903.0  21457.0   10369.0  2372.798426  38.9047  ...
# 2999           9983.0  21188.0   10023.0  2365.752183  38.9047  ...
#
#       total_ytd_pc  multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  \
# 0         0.461690        0.154267            0.154267  1.128699     0.206587
# 1         0.897537        0.103214            0.247651  1.563436     0.309802
# 2         1.249829        0.020136            0.258908  1.914777     0.329937
# 3         1.527287        0.017123            0.261286  2.204443     0.347060
# 4         1.845651        0.056126            0.304728  2.516782     0.403186
# ...            ...             ...                 ...       ...          ...
# 2995      2.483753        0.199366            1.200481  3.562266     1.835852
# 2996      2.613333        0.035210            1.228712  3.471068     1.758770
# 2997      3.014128        0.146234            1.372091  3.463614     1.728318
# 2998      3.181297        0.050436            1.412060  3.403186     1.644574
# 2999      3.478364        0.122443            1.583353  3.360521     1.589697
#
#       zori_yoy  state     region  running_total zori_index
# 0          NaN     GA  Southeast          973.0        NaN
# 1          NaN     GA  Southeast         1624.0        NaN
# 2          NaN     GA  Southeast         1751.0        NaN
# 3          NaN     GA  Southeast         1859.0        NaN
# 4          NaN     GA  Southeast         2213.0        NaN
# ...        ...    ...        ...            ...        ...
# 2995  0.050066     DC   Northest        66429.0        NaN
# 2996  0.048862     DC   Northest        66651.0        NaN
# 2997  0.047143     DC   Northest        67573.0        NaN
# 2998  0.044723     DC   Northest        67891.0        NaN
# 2999  0.045161     DC   Northest        68663.0        NaN
#
# [3000 rows x 23 columns]

# %%
# create running total per 10k people (pop_2023 is population)
homebuilding_2020['running_total_per_10k'] = (homebuilding_2020['running_total'] / homebuilding_2020['pop_2023']) * 10000

homebuilding_2020
# Out:
#             date            name   total  total_ytd  multi_total  \
# 0     2020-01-01     Atlanta, GA  2912.0     2912.0        973.0
# 1     2020-02-01     Atlanta, GA  2742.0     5661.0        651.0
# 2     2020-03-01     Atlanta, GA  2216.0     7883.0        127.0
# 3     2020-04-01     Atlanta, GA  1827.0     9633.0        108.0
# 4     2020-05-01     Atlanta, GA  1970.0    11641.0        354.0
# ...          ...             ...     ...        ...          ...
# 2995  2024-08-01  Washington, DC  2137.0    15660.0       1257.0
# 2996  2024-09-01  Washington, DC   900.0    16477.0        222.0
# 2997  2024-10-01  Washington, DC  1801.0    19004.0        922.0
# 2998  2024-11-01  Washington, DC  1124.0    20058.0        318.0
# 2999  2024-12-01  Washington, DC  1506.0    21931.0        772.0
#
#       multi_total_ytd       rt  multi_rt         zori      lat  ...  \
# 0               973.0   7119.0    1303.0  1368.798323  33.7628  ...
# 1              1562.0   9861.0    1954.0  1373.768759  33.7628  ...
# 2              1633.0  12077.0    2081.0  1382.102627  33.7628  ...
# 3              1648.0  13904.0    2189.0  1390.457345  33.7628  ...
# 4              1922.0  15874.0    2543.0  1393.296553  33.7628  ...
# ...               ...      ...       ...          ...      ...  ...
# 2995           7569.0  22460.0   11575.0  2375.472810  38.9047  ...
# 2996           7747.0  21885.0   11089.0  2383.224478  38.9047  ...
# 2997           8651.0  21838.0   10897.0  2382.780218  38.9047  ...
# 2998           8903.0  21457.0   10369.0  2372.798426  38.9047  ...
# 2999           9983.0  21188.0   10023.0  2365.752183  38.9047  ...
#
#       multi_total_pc  multi_total_ytd_pc     rt_pc  multi_rt_pc  zori_yoy  \
# 0           0.154267            0.154267  1.128699     0.206587       NaN
# 1           0.103214            0.247651  1.563436     0.309802       NaN
# 2           0.020136            0.258908  1.914777     0.329937       NaN
# 3           0.017123            0.261286  2.204443     0.347060       NaN
# 4           0.056126            0.304728  2.516782     0.403186       NaN
# ...              ...                 ...       ...          ...       ...
# 2995        0.199366            1.200481  3.562266     1.835852  0.050066
# 2996        0.035210            1.228712  3.471068     1.758770  0.048862
# 2997        0.146234            1.372091  3.463614     1.728318  0.047143
# 2998        0.050436            1.412060  3.403186     1.644574  0.044723
# 2999        0.122443            1.583353  3.360521     1.589697  0.045161
#
#       state     region  running_total  zori_index running_total_per_10k
# 0        GA  Southeast          973.0         NaN              1.542666
# 1        GA  Southeast         1624.0         NaN              2.574810
# 2        GA  Southeast         1751.0         NaN              2.776165
# 3        GA  Southeast         1859.0         NaN              2.947397
# 4        GA  Southeast         2213.0         NaN              3.508655
# ...     ...        ...            ...         ...                   ...
# 2995     DC   Northest        66429.0         NaN            105.359656
# 2996     DC   Northest        66651.0         NaN            105.711759
# 2997     DC   Northest        67573.0         NaN            107.174097
# 2998     DC   Northest        67891.0         NaN            107.678460
# 2999     DC   Northest        68663.0         NaN            108.902890
#
# [3000 rows x 24 columns]

# %%
# in name, remove the state name and the last comma and space
homebuilding_2020['name'] = homebuilding_2020['name'].str.replace(r',\s.*$', '', regex=True)

# %%
homebuilding_2020
# Out:
#             date        name   total  total_ytd  multi_total  multi_total_ytd  \
# 0     2020-01-01     Atlanta  2912.0     2912.0        973.0            973.0
# 1     2020-02-01     Atlanta  2742.0     5661.0        651.0           1562.0
# 2     2020-03-01     Atlanta  2216.0     7883.0        127.0           1633.0
# 3     2020-04-01     Atlanta  1827.0     9633.0        108.0           1648.0
# 4     2020-05-01     Atlanta  1970.0    11641.0        354.0           1922.0
# ...          ...         ...     ...        ...          ...              ...
# 2995  2024-08-01  Washington  2137.0    15660.0       1257.0           7569.0
# 2996  2024-09-01  Washington   900.0    16477.0        222.0           7747.0
# 2997  2024-10-01  Washington  1801.0    19004.0        922.0           8651.0
# 2998  2024-11-01  Washington  1124.0    20058.0        318.0           8903.0
# 2999  2024-12-01  Washington  1506.0    21931.0        772.0           9983.0
#
#            rt  multi_rt         zori      lat  ...  multi_total_pc  \
# 0      7119.0    1303.0  1368.798323  33.7628  ...        0.154267
# 1      9861.0    1954.0  1373.768759  33.7628  ...        0.103214
# 2     12077.0    2081.0  1382.102627  33.7628  ...        0.020136
# 3     13904.0    2189.0  1390.457345  33.7628  ...        0.017123
# 4     15874.0    2543.0  1393.296553  33.7628  ...        0.056126
# ...       ...       ...          ...      ...  ...             ...
# 2995  22460.0   11575.0  2375.472810  38.9047  ...        0.199366
# 2996  21885.0   11089.0  2383.224478  38.9047  ...        0.035210
# 2997  21838.0   10897.0  2382.780218  38.9047  ...        0.146234
# 2998  21457.0   10369.0  2372.798426  38.9047  ...        0.050436
# 2999  21188.0   10023.0  2365.752183  38.9047  ...        0.122443
#
#       multi_total_ytd_pc     rt_pc  multi_rt_pc  zori_yoy  state     region  \
# 0               0.154267  1.128699     0.206587       NaN     GA  Southeast
# 1               0.247651  1.563436     0.309802       NaN     GA  Southeast
# 2               0.258908  1.914777     0.329937       NaN     GA  Southeast
# 3               0.261286  2.204443     0.347060       NaN     GA  Southeast
# 4               0.304728  2.516782     0.403186       NaN     GA  Southeast
# ...                  ...       ...          ...       ...    ...        ...
# 2995            1.200481  3.562266     1.835852  0.050066     DC   Northest
# 2996            1.228712  3.471068     1.758770  0.048862     DC   Northest
# 2997            1.372091  3.463614     1.728318  0.047143     DC   Northest
# 2998            1.412060  3.403186     1.644574  0.044723     DC   Northest
# 2999            1.583353  3.360521     1.589697  0.045161     DC   Northest
#
#       running_total  zori_index running_total_per_10k
# 0             973.0         NaN              1.542666
# 1            1624.0         NaN              2.574810
# 2            1751.0         NaN              2.776165
# 3            1859.0         NaN              2.947397
# 4            2213.0         NaN              3.508655
# ...             ...         ...                   ...
# 2995        66429.0         NaN            105.359656
# 2996        66651.0         NaN            105.711759
# 2997        67573.0         NaN            107.174097
# 2998        67891.0         NaN            107.678460
# 2999        68663.0         NaN            108.902890
#
# [3000 rows x 24 columns]

# %%
homebuilding_2020.to_csv('data/homebuilding_zori_indexed.csv', index=False)

# %%
# set realtor url
realtor_url = "https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_Metro_History.csv"

realtor_data = pd.read_csv(realtor_url)

realtor_data
# Out:
#        month_date_yyyymm  cbsa_code                             cbsa_title  \
# 0                 202412      35620  New York-Newark-Jersey City, NY-NJ-PA
# 1                 202412      31080     Los Angeles-Long Beach-Anaheim, CA
# 2                 202412      16980     Chicago-Naperville-Elgin, IL-IN-WI
# 3                 202412      19100        Dallas-Fort Worth-Arlington, TX
# 4                 202412      26420   Houston-The Woodlands-Sugar Land, TX
# ...                  ...        ...                                    ...
# 94549             201607      18780                              Craig, CO
# 94550             201607      46900                             Vernon, TX
# 94551             201607      49820                             Zapata, TX
# 94552             201607      37780                              Pecos, TX
# 94553             201607      29500                             Lamesa, TX
#
#        HouseholdRank  median_listing_price  median_listing_price_mm  \
# 0                  1                749000                  -0.0013
# 1                  2               1094000                  -0.0319
# 2                  3                347450                  -0.0346
# 3                  4                422450                  -0.0130
# 4                  5                361405                  -0.0098
# ...              ...                   ...                      ...
# 94549            923                174900                      NaN
# 94550            924                139000                      NaN
# 94551            925                104000                      NaN
# 94552            926                117700                      NaN
# 94553            927                118450                      NaN
#
#        median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                       0.0202                 29297                  -0.1344
# 1                      -0.0055                 12686                  -0.1700
# 2                      -0.0073                 14155                  -0.1598
# 3                      -0.0289                 22744                  -0.1079
# 4                       0.0039                 26614                  -0.0360
# ...                        ...                   ...                      ...
# 94549                      NaN                   173                      NaN
# 94550                      NaN                     3                      NaN
# 94551                      NaN                    27                      NaN
# 94552                      NaN                     5                      NaN
# 94553                      NaN                    12                      NaN
#
#        active_listing_count_yy  ...  average_listing_price  \
# 0                       0.0028  ...                1648167
# 1                       0.2630  ...                2398115
# 2                       0.0636  ...                 515696
# 3                       0.3111  ...                 600314
# 4                       0.2450  ...                 487031
# ...                        ...  ...                    ...
# 94549                      NaN  ...                 204604
# 94550                      NaN  ...                 172800
# 94551                      NaN  ...                 121803
# 94552                      NaN  ...                 101975
# 94553                      NaN  ...                 133733
#
#        average_listing_price_mm  average_listing_price_yy  \
# 0                        0.0067                   -0.0630
# 1                        0.0180                   -0.0783
# 2                       -0.0257                   -0.0355
# 3                       -0.0159                   -0.0448
# 4                       -0.0129                   -0.0344
# ...                         ...                       ...
# 94549                       NaN                       NaN
# 94550                       NaN                       NaN
# 94551                       NaN                       NaN
# 94552                       NaN                       NaN
# 94553                       NaN                       NaN
#
#        total_listing_count  total_listing_count_mm  total_listing_count_yy  \
# 0                    50240                 -0.0274                  0.1692
# 1                    18822                 -0.1603                  0.1937
# 2                    22540                 -0.1740                  0.0425
# 3                    30828                 -0.1221                  0.2187
# 4                    35275                 -0.0490                  0.1991
# ...                    ...                     ...                     ...
# 94549                  195                     NaN                     NaN
# 94550                    5                     NaN                     NaN
# 94551                   27                     NaN                     NaN
# 94552                    5                     NaN                     NaN
# 94553                   14                     NaN                     NaN
#
#        pending_ratio  pending_ratio_mm  pending_ratio_yy  quality_flag
# 0             0.7317            0.1921            0.2503           0.0
# 1             0.4864            0.0222           -0.0788           0.0
# 2             0.5951           -0.0286           -0.0320           0.0
# 3             0.3557           -0.0229           -0.0994           0.0
# 4             0.3262           -0.0203           -0.0492           0.0
# ...              ...               ...               ...           ...
# 94549         0.1272               NaN               NaN           NaN
# 94550         0.6667               NaN               NaN           NaN
# 94551            NaN               NaN               NaN           NaN
# 94552            NaN               NaN               NaN           NaN
# 94553         0.1667               NaN               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
# Extract the first part of the cbsa_title before the first hyphen and the first state abbreviation
realtor_data['cbsa_title'] = realtor_data['cbsa_title'].str.replace(r'^(.*?)-.*?,\s(\w{2}).*$', r'\1, \2')

realtor_data
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gn/T/ipykernel_60425/900176153.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   realtor_data['cbsa_title'] = realtor_data['cbsa_title'].str.replace(r'^(.*?)-.*?,\s(\w{2}).*$', r'\1, \2')
#        month_date_yyyymm  cbsa_code       cbsa_title  HouseholdRank  \
# 0                 202412      35620     New York, NY              1
# 1                 202412      31080  Los Angeles, CA              2
# 2                 202412      16980      Chicago, IL              3
# 3                 202412      19100       Dallas, TX              4
# 4                 202412      26420      Houston, TX              5
# ...                  ...        ...              ...            ...
# 94549             201607      18780        Craig, CO            923
# 94550             201607      46900       Vernon, TX            924
# 94551             201607      49820       Zapata, TX            925
# 94552             201607      37780        Pecos, TX            926
# 94553             201607      29500       Lamesa, TX            927
#
#        median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0                    749000                  -0.0013                   0.0202
# 1                   1094000                  -0.0319                  -0.0055
# 2                    347450                  -0.0346                  -0.0073
# 3                    422450                  -0.0130                  -0.0289
# 4                    361405                  -0.0098                   0.0039
# ...                     ...                      ...                      ...
# 94549                174900                      NaN                      NaN
# 94550                139000                      NaN                      NaN
# 94551                104000                      NaN                      NaN
# 94552                117700                      NaN                      NaN
# 94553                118450                      NaN                      NaN
#
#        active_listing_count  active_listing_count_mm  active_listing_count_yy  \
# 0                     29297                  -0.1344                   0.0028
# 1                     12686                  -0.1700                   0.2630
# 2                     14155                  -0.1598                   0.0636
# 3                     22744                  -0.1079                   0.3111
# 4                     26614                  -0.0360                   0.2450
# ...                     ...                      ...                      ...
# 94549                   173                      NaN                      NaN
# 94550                     3                      NaN                      NaN
# 94551                    27                      NaN                      NaN
# 94552                     5                      NaN                      NaN
# 94553                    12                      NaN                      NaN
#
#        ...  average_listing_price  average_listing_price_mm  \
# 0      ...                1648167                    0.0067
# 1      ...                2398115                    0.0180
# 2      ...                 515696                   -0.0257
# 3      ...                 600314                   -0.0159
# 4      ...                 487031                   -0.0129
# ...    ...                    ...                       ...
# 94549  ...                 204604                       NaN
# 94550  ...                 172800                       NaN
# 94551  ...                 121803                       NaN
# 94552  ...                 101975                       NaN
# 94553  ...                 133733                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       -0.0630                50240                 -0.0274
# 1                       -0.0783                18822                 -0.1603
# 2                       -0.0355                22540                 -0.1740
# 3                       -0.0448                30828                 -0.1221
# 4                       -0.0344                35275                 -0.0490
# ...                         ...                  ...                     ...
# 94549                       NaN                  195                     NaN
# 94550                       NaN                    5                     NaN
# 94551                       NaN                   27                     NaN
# 94552                       NaN                    5                     NaN
# 94553                       NaN                   14                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                      0.1692         0.7317            0.1921
# 1                      0.1937         0.4864            0.0222
# 2                      0.0425         0.5951           -0.0286
# 3                      0.2187         0.3557           -0.0229
# 4                      0.1991         0.3262           -0.0203
# ...                       ...            ...               ...
# 94549                     NaN         0.1272               NaN
# 94550                     NaN         0.6667               NaN
# 94551                     NaN            NaN               NaN
# 94552                     NaN            NaN               NaN
# 94553                     NaN         0.1667               NaN
#
#        pending_ratio_yy  quality_flag
# 0                0.2503           0.0
# 1               -0.0788           0.0
# 2               -0.0320           0.0
# 3               -0.0994           0.0
# 4               -0.0492           0.0
# ...                 ...           ...
# 94549               NaN           NaN
# 94550               NaN           NaN
# 94551               NaN           NaN
# 94552               NaN           NaN
# 94553               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
# convert 'month_date_yyyymm' to datetime
realtor_data['month_date_yyyymm'] = pd.to_datetime(realtor_data['month_date_yyyymm'], format='%Y%m')

realtor_data
# Out:
#       month_date_yyyymm  cbsa_code       cbsa_title  HouseholdRank  \
# 0            2024-12-01      35620     New York, NY              1
# 1            2024-12-01      31080  Los Angeles, CA              2
# 2            2024-12-01      16980      Chicago, IL              3
# 3            2024-12-01      19100       Dallas, TX              4
# 4            2024-12-01      26420      Houston, TX              5
# ...                 ...        ...              ...            ...
# 94549        2016-07-01      18780        Craig, CO            923
# 94550        2016-07-01      46900       Vernon, TX            924
# 94551        2016-07-01      49820       Zapata, TX            925
# 94552        2016-07-01      37780        Pecos, TX            926
# 94553        2016-07-01      29500       Lamesa, TX            927
#
#        median_listing_price  median_listing_price_mm  median_listing_price_yy  \
# 0                    749000                  -0.0013                   0.0202
# 1                   1094000                  -0.0319                  -0.0055
# 2                    347450                  -0.0346                  -0.0073
# 3                    422450                  -0.0130                  -0.0289
# 4                    361405                  -0.0098                   0.0039
# ...                     ...                      ...                      ...
# 94549                174900                      NaN                      NaN
# 94550                139000                      NaN                      NaN
# 94551                104000                      NaN                      NaN
# 94552                117700                      NaN                      NaN
# 94553                118450                      NaN                      NaN
#
#        active_listing_count  active_listing_count_mm  active_listing_count_yy  \
# 0                     29297                  -0.1344                   0.0028
# 1                     12686                  -0.1700                   0.2630
# 2                     14155                  -0.1598                   0.0636
# 3                     22744                  -0.1079                   0.3111
# 4                     26614                  -0.0360                   0.2450
# ...                     ...                      ...                      ...
# 94549                   173                      NaN                      NaN
# 94550                     3                      NaN                      NaN
# 94551                    27                      NaN                      NaN
# 94552                     5                      NaN                      NaN
# 94553                    12                      NaN                      NaN
#
#        ...  average_listing_price  average_listing_price_mm  \
# 0      ...                1648167                    0.0067
# 1      ...                2398115                    0.0180
# 2      ...                 515696                   -0.0257
# 3      ...                 600314                   -0.0159
# 4      ...                 487031                   -0.0129
# ...    ...                    ...                       ...
# 94549  ...                 204604                       NaN
# 94550  ...                 172800                       NaN
# 94551  ...                 121803                       NaN
# 94552  ...                 101975                       NaN
# 94553  ...                 133733                       NaN
#
#        average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       -0.0630                50240                 -0.0274
# 1                       -0.0783                18822                 -0.1603
# 2                       -0.0355                22540                 -0.1740
# 3                       -0.0448                30828                 -0.1221
# 4                       -0.0344                35275                 -0.0490
# ...                         ...                  ...                     ...
# 94549                       NaN                  195                     NaN
# 94550                       NaN                    5                     NaN
# 94551                       NaN                   27                     NaN
# 94552                       NaN                    5                     NaN
# 94553                       NaN                   14                     NaN
#
#        total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                      0.1692         0.7317            0.1921
# 1                      0.1937         0.4864            0.0222
# 2                      0.0425         0.5951           -0.0286
# 3                      0.2187         0.3557           -0.0229
# 4                      0.1991         0.3262           -0.0203
# ...                       ...            ...               ...
# 94549                     NaN         0.1272               NaN
# 94550                     NaN         0.6667               NaN
# 94551                     NaN            NaN               NaN
# 94552                     NaN            NaN               NaN
# 94553                     NaN         0.1667               NaN
#
#        pending_ratio_yy  quality_flag
# 0                0.2503           0.0
# 1               -0.0788           0.0
# 2               -0.0320           0.0
# 3               -0.0994           0.0
# 4               -0.0492           0.0
# ...                 ...           ...
# 94549               NaN           NaN
# 94550               NaN           NaN
# 94551               NaN           NaN
# 94552               NaN           NaN
# 94553               NaN           NaN
#
# [94554 rows x 41 columns]

# %%
realtor_data.columns
# Out:
# Index(['month_date_yyyymm', 'cbsa_code', 'cbsa_title', 'HouseholdRank',
#        'median_listing_price', 'median_listing_price_mm',
#        'median_listing_price_yy', 'active_listing_count',
#        'active_listing_count_mm', 'active_listing_count_yy',
#        'median_days_on_market', 'median_days_on_market_mm',
#        'median_days_on_market_yy', 'new_listing_count', 'new_listing_count_mm',
#        'new_listing_count_yy', 'price_increased_count',
#        'price_increased_count_mm', 'price_increased_count_yy',
#        'price_reduced_count', 'price_reduced_count_mm',
#        'price_reduced_count_yy', 'pending_listing_count',
#        'pending_listing_count_mm', 'pending_listing_count_yy',
#        'median_listing_price_per_square_foot',
#        'median_listing_price_per_square_foot_mm',
#        'median_listing_price_per_square_foot_yy', 'median_square_feet',
#        'median_square_feet_mm', 'median_square_feet_yy',
#        'average_listing_price', 'average_listing_price_mm',
#        'average_listing_price_yy', 'total_listing_count',
#        'total_listing_count_mm', 'total_listing_count_yy', 'pending_ratio',
#        'pending_ratio_mm', 'pending_ratio_yy', 'quality_flag'],
#       dtype='object')

# %%
realtor_data = realtor_data[['month_date_yyyymm','cbsa_code','cbsa_title', 'new_listing_count']]

realtor_data.columns = ['date', 'id', 'name', 'new_listings']

realtor_data
# Out:
#             date     id             name  new_listings
# 0     2024-12-01  35620     New York, NY          7948
# 1     2024-12-01  31080  Los Angeles, CA          4324
# 2     2024-12-01  16980      Chicago, IL          4936
# 3     2024-12-01  19100       Dallas, TX          6278
# 4     2024-12-01  26420      Houston, TX          7070
# ...          ...    ...              ...           ...
# 94549 2016-07-01  18780        Craig, CO            28
# 94550 2016-07-01  46900       Vernon, TX             0
# 94551 2016-07-01  49820       Zapata, TX             4
# 94552 2016-07-01  37780        Pecos, TX             0
# 94553 2016-07-01  29500       Lamesa, TX             0
#
# [94554 rows x 4 columns]

# %%
# import the top_metros data. It's a JSON with a list.
import json

with open('data/top_metros.json') as f:
    top_metros = json.load(f)

# restrict the realtor data to only the top metros
realtor_data = realtor_data[realtor_data['name'].isin(top_metros)]

realtor_data
# Out:
#             date     id                name  new_listings
# 0     2024-12-01  35620        New York, NY          7948
# 1     2024-12-01  31080     Los Angeles, CA          4324
# 2     2024-12-01  16980         Chicago, IL          4936
# 3     2024-12-01  19100          Dallas, TX          6278
# 4     2024-12-01  26420         Houston, TX          7070
# ...          ...    ...                 ...           ...
# 93673 2016-07-01  15380         Buffalo, NY          1248
# 93674 2016-07-01  25540        Hartford, CT          1956
# 93676 2016-07-01  13820      Birmingham, AL          1936
# 93678 2016-07-01  41620  Salt Lake City, UT          1984
# 93679 2016-07-01  24340    Grand Rapids, MI           428
#
# [4590 rows x 4 columns]

# %%
# convert metros.date to datetime
metros['date'] = pd.to_datetime(metros['date'])

metros.dtypes
# Out:
# name                  object
# date          datetime64[ns]
# zori                 float64
# lat                  float64
# lng                  float64
# pop_2023             float64
# state                 object
# region                object
# zori_index           float64
# dtype: object

# %%
# add the pop_2023 column to the realtor data. It will be merged on the name and date columns
realtor_data = realtor_data.merge(metros[['name', 'date', 'pop_2023']], on=['name', 'date'], how='left')

# %%
# sort by date, then name with earliest date first
realtor_data = realtor_data.sort_values(['date', 'name'])

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
# [4590 rows x 5 columns]

# %%
# Calculate the cumulative sum of new_listings for each id since the earliest date
realtor_data['cumulative_new_listings'] = realtor_data.groupby('id')['new_listings'].cumsum()

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings
# 4553                    11888
# 4570                     3668
# 4564                     5048
# 4587                     1936
# 4554                     6268
# ...                       ...
# 35                     130238
# 13                     495438
# 16                     617218
# 32                     279784
# 6                      839272
#
# [4590 rows x 6 columns]

# %%
# add a state column that extracts the state from the name column
realtor_data['state'] = realtor_data['name'].str.extract(r',\s(.*)$')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 4553 2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 4570 2016-07-01  12420          Austin, TX          3668  2473275.0
# 4564 2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 4587 2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4554 2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 35   2024-12-01  41940        San Jose, CA           352  1945767.0
# 13   2024-12-01  42660         Seattle, WA          1608  4044837.0
# 16   2024-12-01  45300           Tampa, FL          4614  3342963.0
# 32   2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 6    2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state
# 4553                    11888    GA
# 4570                     3668    TX
# 4564                     5048    MD
# 4587                     1936    AL
# 4554                     6268    MA
# ...                       ...   ...
# 35                     130238    CA
# 13                     495438    WA
# 16                     617218    FL
# 32                     279784    VA
# 6                      839272    DC
#
# [4590 rows x 7 columns]

# %%
# add region col
realtor_data = realtor_data.merge(regions, on='state', how='left')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region
# 0                       11888    GA  Southeast
# 1                        3668    TX  Southwest
# 2                        5048    MD   Northest
# 3                        1936    AL  Southeast
# 4                        6268    MA   Northest
# ...                       ...   ...        ...
# 4585                   130238    CA       West
# 4586                   495438    WA       West
# 4587                   617218    FL  Southeast
# 4588                   279784    VA  Southeast
# 4589                   839272    DC   Northest
#
# [4590 rows x 8 columns]

# %%
# add zori and zori_index from metros to realtor_data
realtor_data = realtor_data.merge(metros[['name', 'date', 'zori', 'zori_index']], on=['name', 'date'], how='left')

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index
# 0                       11888    GA  Southeast  1133.885137   82.561987
# 1                        3668    TX  Southwest  1286.087094   90.271224
# 2                        5048    MD   Northest  1374.881054   94.719129
# 3                        1936    AL  Southeast   922.773482   90.478772
# 4                        6268    MA   Northest  2129.591065   91.341245
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  111.343869
# 4586                   495438    WA       West  2220.617862  124.087570
# 4587                   617218    FL  Southeast  2057.590695  152.851085
# 4588                   279784    VA  Southeast  1764.030482  142.402366
# 4589                   839272    DC   Northest  2372.478358  123.524705
#
# [4590 rows x 10 columns]

# %%
# make the zori_index an index of zori where july 2016 is 100
base_zori = metros[metros['date'] == '2016-07-01'].set_index('name')['zori']

realtor_data['zori_index'] = realtor_data.apply(lambda row: (row['zori'] / base_zori[row['name']]) * 100 if row['name'] in base_zori else None, axis=1)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
# [4590 rows x 10 columns]

# %%
# create a new_listings per 10k people column and cumulative_new_listings per 10k people column
realtor_data['new_per_10k'] = (realtor_data['new_listings'] / realtor_data['pop_2023']) * 10000

realtor_data['cumulative_per_10k'] = (realtor_data['cumulative_new_listings'] / realtor_data['pop_2023']) * 10000

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k
# 0       18.848118           18.848118
# 1       14.830538           14.830538
# 2       17.810294           17.810294
# 3       16.347347           16.347347
# 4       12.741964           12.741964
# ...           ...                 ...
# 4585     1.809055          669.340163
# 4586     3.975438         1224.865180
# 4587    13.802127         1846.320166
# 4588     7.900764         1565.515069
# 4589     5.490902         1331.126610
#
# [4590 rows x 12 columns]

# %%
# add a yoy change column for zori
realtor_data['zori_yoy'] = realtor_data.groupby('name')['zori'].pct_change(12)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy
# 0       18.848118           18.848118       NaN
# 1       14.830538           14.830538       NaN
# 2       17.810294           17.810294       NaN
# 3       16.347347           16.347347       NaN
# 4       12.741964           12.741964       NaN
# ...           ...                 ...       ...
# 4585     1.809055          669.340163  0.046295
# 4586     3.975438         1224.865180  0.038656
# 4587    13.802127         1846.320166  0.024556
# 4588     7.900764         1565.515069  0.050527
# 4589     5.490902         1331.126610  0.044968
#
# [4590 rows x 13 columns]

# %%
# create a new_listings_yoy column
realtor_data['new_listings_yoy'] = realtor_data.groupby('name')['new_listings'].pct_change(12)

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy  new_listings_yoy
# 0       18.848118           18.848118       NaN               NaN
# 1       14.830538           14.830538       NaN               NaN
# 2       17.810294           17.810294       NaN               NaN
# 3       16.347347           16.347347       NaN               NaN
# 4       12.741964           12.741964       NaN               NaN
# ...           ...                 ...       ...               ...
# 4585     1.809055          669.340163  0.046295         -0.185185
# 4586     3.975438         1224.865180  0.038656         -0.073733
# 4587    13.802127         1846.320166  0.024556          0.080056
# 4588     7.900764         1565.515069  0.050527          0.168874
# 4589     5.490902         1331.126610  0.044968         -0.035117
#
# [4590 rows x 14 columns]

# %%
# Create a mask for dates since January 2020
mask = realtor_data['date'] >= '2020-01-01'

# Initialize the new column with NaN values
realtor_data['cumulative_since_2020'] = pd.NA

# Calculate the cumulative sum for dates since January 2020
realtor_data.loc[mask, 'cumulative_since_2020'] = realtor_data[mask].groupby('name')['new_listings'].cumsum()

realtor_data
# Out:
#            date     id                name  new_listings   pop_2023  \
# 0    2016-07-01  12060         Atlanta, GA         11888  6307261.0
# 1    2016-07-01  12420          Austin, TX          3668  2473275.0
# 2    2016-07-01  12580       Baltimore, MD          5048  2834316.0
# 3    2016-07-01  13820      Birmingham, AL          1936  1184290.0
# 4    2016-07-01  14460          Boston, MA          6268  4919179.0
# ...         ...    ...                 ...           ...        ...
# 4585 2024-12-01  41940        San Jose, CA           352  1945767.0
# 4586 2024-12-01  42660         Seattle, WA          1608  4044837.0
# 4587 2024-12-01  45300           Tampa, FL          4614  3342963.0
# 4588 2024-12-01  47260  Virginia Beach, VA          1412  1787169.0
# 4589 2024-12-01  47900      Washington, DC          3462  6304975.0
#
#       cumulative_new_listings state     region         zori  zori_index  \
# 0                       11888    GA  Southeast  1133.885137  100.000000
# 1                        3668    TX  Southwest  1286.087094  100.000000
# 2                        5048    MD   Northest  1374.881054  100.000000
# 3                        1936    AL  Southeast   922.773482  100.000000
# 4                        6268    MA   Northest  2129.591065  100.000000
# ...                       ...   ...        ...          ...         ...
# 4585                   130238    CA       West  3296.470892  120.084045
# 4586                   495438    WA       West  2220.617862  143.926821
# 4587                   617218    FL  Southeast  2057.590695  180.133399
# 4588                   279784    VA  Southeast  1764.030482  156.396560
# 4589                   839272    DC   Northest  2372.478358  132.935901
#
#       new_per_10k  cumulative_per_10k  zori_yoy  new_listings_yoy  \
# 0       18.848118           18.848118       NaN               NaN
# 1       14.830538           14.830538       NaN               NaN
# 2       17.810294           17.810294       NaN               NaN
# 3       16.347347           16.347347       NaN               NaN
# 4       12.741964           12.741964       NaN               NaN
# ...           ...                 ...       ...               ...
# 4585     1.809055          669.340163  0.046295         -0.185185
# 4586     3.975438         1224.865180  0.038656         -0.073733
# 4587    13.802127         1846.320166  0.024556          0.080056
# 4588     7.900764         1565.515069  0.050527          0.168874
# 4589     5.490902         1331.126610  0.044968         -0.035117
#
#      cumulative_since_2020
# 0                     <NA>
# 1                     <NA>
# 2                     <NA>
# 3                     <NA>
# 4                     <NA>
# ...                    ...
# 4585                 75106
# 4586                258246
# 4587                349814
# 4588                153312
# 4589                462458
#
# [4590 rows x 15 columns]

# %%
# make it numeric, coerce errors to NaN
realtor_data['cumulative_since_2020'] = pd.to_numeric(realtor_data['cumulative_since_2020'], errors='coerce')

realtor_data.dtypes
# Out:
# date                       datetime64[ns]
# id                                  int64
# name                               object
# new_listings                        int64
# pop_2023                          float64
# cumulative_new_listings             int64
# state                              object
# region                             object
# zori                              float64
# zori_index                        float64
# new_per_10k                       float64
# cumulative_per_10k                float64
# zori_yoy                          float64
# new_listings_yoy                  float64
# cumulative_since_2020             float64
# dtype: object

# %%
# make it per 10k people
realtor_data['cumulative_since_2020'] = (realtor_data['cumulative_since_2020'] / realtor_data['pop_2023']) * 10000

# %%
realtor_data.to_csv('data/realtor_zori_indexed.csv', index=False)
