# %%
import pandas as pd

# %%
metro_url = "https://files.zillowstatic.com/research/public_csvs/zori/Metro_zori_uc_sfrcondomfr_sm_month.csv?t=1734717130"

# %%
# Read in ZORI metro data
zori_metro_wide = pd.read_csv(metro_url)
zori_metro_wide
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0      102001         0    United States    country       NaN  1197.135014
# 1      394913         1     New York, NY        msa        NY  2233.141451
# 2      753899         2  Los Angeles, CA        msa        CA  1809.922576
# 3      394463         3      Chicago, IL        msa        IL  1400.342984
# 4      394514         4       Dallas, TX        msa        TX  1095.378833
# ..        ...       ...              ...        ...       ...          ...
# 603    394996       915     Portales, NM        msa        NM          NaN
# 604    394805       916   Los Alamos, NM        msa        NM          NaN
# 605    786253       921  Brownsville, TN        msa        TN          NaN
# 606    394342       929     Atchison, KS        msa        KS          NaN
# 607    753880       930    Fairfield, IA        msa        IA          NaN
#
#       2015-02-28   2015-03-31   2015-04-30   2015-05-31  ...   2024-05-31  \
# 0    1203.668597  1212.639047  1221.659620  1230.896254  ...  1952.212690
# 1    2247.559592  2265.802262  2285.735153  2300.826521  ...  3182.280631
# 2    1822.546326  1838.656155  1852.451917  1866.850931  ...  2907.654651
# 3    1407.136301  1416.670054  1425.972644  1436.236253  ...  2021.586545
# 4    1100.367576  1108.336454  1120.217111  1130.017885  ...  1746.791703
# ..           ...          ...          ...          ...  ...          ...
# 603          NaN          NaN          NaN          NaN  ...   847.064876
# 604          NaN          NaN          NaN          NaN  ...          NaN
# 605          NaN          NaN          NaN          NaN  ...          NaN
# 606          NaN          NaN          NaN          NaN  ...          NaN
# 607          NaN          NaN          NaN          NaN  ...          NaN
#
#       2024-06-30   2024-07-31   2024-08-31   2024-09-30   2024-10-31  \
# 0    1963.530556  1972.333743  1976.508015  1977.568303  1973.864441
# 1    3210.356517  3227.624815  3233.030430  3222.421335  3208.121467
# 2    2921.723436  2935.412053  2941.093233  2945.174113  2942.243481
# 3    2039.379377  2048.680609  2051.979728  2050.375128  2048.724488
# 4    1753.697018  1760.069195  1762.709157  1759.097054  1751.891152
# ..           ...          ...          ...          ...          ...
# 603   847.055257   850.361436   849.862364   841.379793   850.806381
# 604          NaN          NaN          NaN          NaN          NaN
# 605          NaN          NaN          NaN          NaN          NaN
# 606          NaN          NaN          NaN          NaN          NaN
# 607          NaN          NaN          NaN          NaN          NaN
#
#       2024-11-30   2024-12-31   2025-01-31   2025-02-28
# 0    1970.768273  1967.300532  1971.799915  1980.162671
# 1    3196.671310  3190.753169  3200.395740  3220.610276
# 2    2938.727400  2931.113174  2952.828971  2975.013379
# 3    2050.069392  2053.872732  2061.194046  2077.000461
# 4    1743.521853  1736.717800  1735.122854  1740.965116
# ..           ...          ...          ...          ...
# 603   845.972142   861.496430   862.441578   852.638889
# 604          NaN  2779.162904  2722.935304  2733.333333
# 605          NaN          NaN          NaN   962.500000
# 606          NaN          NaN          NaN  1025.000000
# 607          NaN          NaN  1011.930926   980.000000
#
# [608 rows x 127 columns]

# %% [markdown]
# ## Melting df

# %%
index_cols = ['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName']

# %%
# melt df
zori_metro_long = pd.melt(
    zori_metro_wide,
    id_vars = index_cols,
    value_vars = [col for col in zori_metro_wide.columns if col not in index_cols],
    var_name = "date",
    value_name = "zori"
)

zori_metro_long
# Out:
#        RegionID  SizeRank       RegionName RegionType StateName        date  \
# 0        102001         0    United States    country       NaN  2015-01-31
# 1        394913         1     New York, NY        msa        NY  2015-01-31
# 2        753899         2  Los Angeles, CA        msa        CA  2015-01-31
# 3        394463         3      Chicago, IL        msa        IL  2015-01-31
# 4        394514         4       Dallas, TX        msa        TX  2015-01-31
# ...         ...       ...              ...        ...       ...         ...
# 74171    394996       915     Portales, NM        msa        NM  2025-02-28
# 74172    394805       916   Los Alamos, NM        msa        NM  2025-02-28
# 74173    786253       921  Brownsville, TN        msa        TN  2025-02-28
# 74174    394342       929     Atchison, KS        msa        KS  2025-02-28
# 74175    753880       930    Fairfield, IA        msa        IA  2025-02-28
#
#               zori
# 0      1197.135014
# 1      2233.141451
# 2      1809.922576
# 3      1400.342984
# 4      1095.378833
# ...            ...
# 74171   852.638889
# 74172  2733.333333
# 74173   962.500000
# 74174  1025.000000
# 74175   980.000000
#
# [74176 rows x 7 columns]

# %%
zori_metro_long['date'] = pd.to_datetime(zori_metro_long['date'])

zori_metro_long
# Out:
#        RegionID  SizeRank       RegionName RegionType StateName       date  \
# 0        102001         0    United States    country       NaN 2015-01-31
# 1        394913         1     New York, NY        msa        NY 2015-01-31
# 2        753899         2  Los Angeles, CA        msa        CA 2015-01-31
# 3        394463         3      Chicago, IL        msa        IL 2015-01-31
# 4        394514         4       Dallas, TX        msa        TX 2015-01-31
# ...         ...       ...              ...        ...       ...        ...
# 74171    394996       915     Portales, NM        msa        NM 2025-02-28
# 74172    394805       916   Los Alamos, NM        msa        NM 2025-02-28
# 74173    786253       921  Brownsville, TN        msa        TN 2025-02-28
# 74174    394342       929     Atchison, KS        msa        KS 2025-02-28
# 74175    753880       930    Fairfield, IA        msa        IA 2025-02-28
#
#               zori
# 0      1197.135014
# 1      2233.141451
# 2      1809.922576
# 3      1400.342984
# 4      1095.378833
# ...            ...
# 74171   852.638889
# 74172  2733.333333
# 74173   962.500000
# 74174  1025.000000
# 74175   980.000000
#
# [74176 rows x 7 columns]

# %%
# create a df for just the US at large
zori_us = zori_metro_long[zori_metro_long['RegionName'] == 'United States']

zori_us
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName       date  \
# 0        102001         0  United States    country       NaN 2015-01-31
# 608      102001         0  United States    country       NaN 2015-02-28
# 1216     102001         0  United States    country       NaN 2015-03-31
# 1824     102001         0  United States    country       NaN 2015-04-30
# 2432     102001         0  United States    country       NaN 2015-05-31
# ...         ...       ...            ...        ...       ...        ...
# 71136    102001         0  United States    country       NaN 2024-10-31
# 71744    102001         0  United States    country       NaN 2024-11-30
# 72352    102001         0  United States    country       NaN 2024-12-31
# 72960    102001         0  United States    country       NaN 2025-01-31
# 73568    102001         0  United States    country       NaN 2025-02-28
#
#               zori
# 0      1197.135014
# 608    1203.668597
# 1216   1212.639047
# 1824   1221.659620
# 2432   1230.896254
# ...            ...
# 71136  1973.864441
# 71744  1970.768273
# 72352  1967.300532
# 72960  1971.799915
# 73568  1980.162671
#
# [122 rows x 7 columns]

# %%
# save this to a csv
zori_us.to_csv('data/zori_us.csv', index = False)

# %%
cities = pd.read_csv('data/uscities.csv')
cities
# Out:
#                  city      city_ascii state_id    state_name  county_fips  \
# 0            New York        New York       NY      New York        36081
# 1         Los Angeles     Los Angeles       CA    California         6037
# 2             Chicago         Chicago       IL      Illinois        17031
# 3               Miami           Miami       FL       Florida        12086
# 4             Houston         Houston       TX         Texas        48201
# ...               ...             ...      ...           ...          ...
# 31115          Kohatk          Kohatk       AZ       Arizona         4021
# 31116       Ironville       Ironville       PA  Pennsylvania        42013
# 31117         Newkirk         Newkirk       NM    New Mexico        35019
# 31118  Falcon Village  Falcon Village       TX         Texas        48427
# 31119     Millerstown     Millerstown       PA  Pennsylvania        42013
#
#        county_name      lat       lng  population  density source  military  \
# 0           Queens  40.6943  -73.9249    18908608  11080.3  shape     False
# 1      Los Angeles  34.1141 -118.4068    11922389   3184.7  shape     False
# 2             Cook  41.8375  -87.6866     8497759   4614.5  shape     False
# 3       Miami-Dade  25.7840  -80.2101     6080145   4758.9  shape     False
# 4           Harris  29.7860  -95.3885     5970127   1384.0  shape     False
# ...            ...      ...       ...         ...      ...    ...       ...
# 31115        Pinal  32.5781 -112.0032           0     77.3  shape     False
# 31116        Blair  40.6586  -78.2155           0     59.2  shape     False
# 31117    Guadalupe  35.0635 -104.2715           0      0.0  shape     False
# 31118        Starr  26.5652  -99.1341           0     38.9  shape     False
# 31119        Blair  40.2771  -78.3029           0     28.0  shape     False
#
#        incorporated             timezone  ranking  \
# 0              True     America/New_York        1
# 1              True  America/Los_Angeles        1
# 2              True      America/Chicago        1
# 3              True     America/New_York        1
# 4              True      America/Chicago        1
# ...             ...                  ...      ...
# 31115         False      America/Phoenix        3
# 31116         False     America/New_York        3
# 31117         False       America/Denver        3
# 31118         False      America/Chicago        3
# 31119         False     America/New_York        3
#
#                                                     zips          id
# 0      11229 11228 11226 11225 11224 11222 11221 1122...  1840034016
# 1      91367 90291 90293 90292 91316 91311 90035 9003...  1840020491
# 2      60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3      33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4      77069 77068 77061 77060 77063 77062 77065 7706...  1840020925
# ...                                                  ...         ...
# 31115                                              85634  1840022983
# 31116                                              16686  1840152922
# 31117                                              88417  1840024978
# 31118                                              78545  1840018314
# 31119                                              16662  1840153020
#
# [31120 rows x 17 columns]

# %%
# create an aligned name column

# create a name column with the City, StateID format
cities["name"] = cities["city"] + ", " + cities["state_id"]

# rename name column in zori df
zori_metro_long.rename(
    columns={
        "RegionName":"name"
    },
    inplace=True
)

# %%
cities['name']
# Out:
# 0              New York, NY
# 1           Los Angeles, CA
# 2               Chicago, IL
# 3                 Miami, FL
# 4               Houston, TX
#                 ...
# 31115            Kohatk, AZ
# 31116         Ironville, PA
# 31117           Newkirk, NM
# 31118    Falcon Village, TX
# 31119       Millerstown, PA
# Name: name, Length: 31120, dtype: object

# %%
# Merge the two DataFrames
zori_metro_long = zori_metro_long.merge(
    cities[['name', 'lat', 'lng']],  # Select only relevant columns from `cities`
    on='name',
    how='left'
)

zori_metro_long
# Out:
#        RegionID  SizeRank             name RegionType StateName       date  \
# 0        102001         0    United States    country       NaN 2015-01-31
# 1        394913         1     New York, NY        msa        NY 2015-01-31
# 2        753899         2  Los Angeles, CA        msa        CA 2015-01-31
# 3        394463         3      Chicago, IL        msa        IL 2015-01-31
# 4        394514         4       Dallas, TX        msa        TX 2015-01-31
# ...         ...       ...              ...        ...       ...        ...
# 74171    394996       915     Portales, NM        msa        NM 2025-02-28
# 74172    394805       916   Los Alamos, NM        msa        NM 2025-02-28
# 74173    786253       921  Brownsville, TN        msa        TN 2025-02-28
# 74174    394342       929     Atchison, KS        msa        KS 2025-02-28
# 74175    753880       930    Fairfield, IA        msa        IA 2025-02-28
#
#               zori      lat       lng
# 0      1197.135014      NaN       NaN
# 1      2233.141451  40.6943  -73.9249
# 2      1809.922576  34.1141 -118.4068
# 3      1400.342984  41.8375  -87.6866
# 4      1095.378833  32.7935  -96.7667
# ...            ...      ...       ...
# 74171   852.638889  34.1754 -103.3565
# 74172  2733.333333  35.8927 -106.2862
# 74173   962.500000  35.5890  -89.2578
# 74174  1025.000000  39.5625  -95.1367
# 74175   980.000000  41.0064  -91.9667
#
# [74176 rows x 9 columns]

# %%
metro_pops = pd.read_csv('data/metro_pop_2023.csv')

metro_pops
# Out:
#                     name   pop_2023
# 0          United States  335893238
# 1           New York, NY   19498249
# 2        Los Angeles, CA   12799100
# 3            Chicago, IL    9262825
# 4             Dallas, TX    8100037
# ...                  ...        ...
# 4450        Hartford, CT    1151543
# 4451          Tucson, AZ    1063162
# 4452       Rochester, NY    1052087
# 4453  Urban Honolulu, HI     989408
# 4454     New Orleans, LA     962165
#
# [4455 rows x 2 columns]

# %%
# Merge the two DataFrames
zori_metro_long = zori_metro_long.merge(
    metro_pops[['name', 'pop_2023']],  # Select only relevant columns from `metro_pops`
    on='name',
    how='left'
)

zori_metro_long
# Out:
#         RegionID  SizeRank             name RegionType StateName       date  \
# 0         102001         0    United States    country       NaN 2015-01-31
# 1         102001         0    United States    country       NaN 2015-01-31
# 2         102001         0    United States    country       NaN 2015-01-31
# 3         102001         0    United States    country       NaN 2015-01-31
# 4         102001         0    United States    country       NaN 2015-01-31
# ...          ...       ...              ...        ...       ...        ...
# 610971    394996       915     Portales, NM        msa        NM 2025-02-28
# 610972    394805       916   Los Alamos, NM        msa        NM 2025-02-28
# 610973    786253       921  Brownsville, TN        msa        TN 2025-02-28
# 610974    394342       929     Atchison, KS        msa        KS 2025-02-28
# 610975    753880       930    Fairfield, IA        msa        IA 2025-02-28
#
#                zori      lat       lng     pop_2023
# 0       1197.135014      NaN       NaN  335893238.0
# 1       1197.135014      NaN       NaN  335893238.0
# 2       1197.135014      NaN       NaN  335893238.0
# 3       1197.135014      NaN       NaN  335893238.0
# 4       1197.135014      NaN       NaN  335893238.0
# ...             ...      ...       ...          ...
# 610971   852.638889  34.1754 -103.3565          NaN
# 610972  2733.333333  35.8927 -106.2862          NaN
# 610973   962.500000  35.5890  -89.2578          NaN
# 610974  1025.000000  39.5625  -95.1367          NaN
# 610975   980.000000  41.0064  -91.9667          NaN
#
# [610976 rows x 10 columns]

# %%
# drop cols
zori_metro_long.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'], inplace=True)

zori_metro_long
# Out:
#                    name       date         zori      lat       lng  \
# 0         United States 2015-01-31  1197.135014      NaN       NaN
# 1         United States 2015-01-31  1197.135014      NaN       NaN
# 2         United States 2015-01-31  1197.135014      NaN       NaN
# 3         United States 2015-01-31  1197.135014      NaN       NaN
# 4         United States 2015-01-31  1197.135014      NaN       NaN
# ...                 ...        ...          ...      ...       ...
# 610971     Portales, NM 2025-02-28   852.638889  34.1754 -103.3565
# 610972   Los Alamos, NM 2025-02-28  2733.333333  35.8927 -106.2862
# 610973  Brownsville, TN 2025-02-28   962.500000  35.5890  -89.2578
# 610974     Atchison, KS 2025-02-28  1025.000000  39.5625  -95.1367
# 610975    Fairfield, IA 2025-02-28   980.000000  41.0064  -91.9667
#
#            pop_2023
# 0       335893238.0
# 1       335893238.0
# 2       335893238.0
# 3       335893238.0
# 4       335893238.0
# ...             ...
# 610971          NaN
# 610972          NaN
# 610973          NaN
# 610974          NaN
# 610975          NaN
#
# [610976 rows x 6 columns]

# %%
# drop all perfect duplicate rows
zori_metro_long.drop_duplicates(inplace=True)

zori_metro_long
# Out:
#                    name       date         zori      lat       lng  \
# 0         United States 2015-01-31  1197.135014      NaN       NaN
# 81         New York, NY 2015-01-31  2233.141451  40.6943  -73.9249
# 162     Los Angeles, CA 2015-01-31  1809.922576  34.1141 -118.4068
# 243         Chicago, IL 2015-01-31  1400.342984  41.8375  -87.6866
# 324          Dallas, TX 2015-01-31  1095.378833  32.7935  -96.7667
# ...                 ...        ...          ...      ...       ...
# 610971     Portales, NM 2025-02-28   852.638889  34.1754 -103.3565
# 610972   Los Alamos, NM 2025-02-28  2733.333333  35.8927 -106.2862
# 610973  Brownsville, TN 2025-02-28   962.500000  35.5890  -89.2578
# 610974     Atchison, KS 2025-02-28  1025.000000  39.5625  -95.1367
# 610975    Fairfield, IA 2025-02-28   980.000000  41.0064  -91.9667
#
#            pop_2023
# 0       335893238.0
# 81       19498249.0
# 162      12799100.0
# 243       9262825.0
# 324       8100037.0
# ...             ...
# 610971          NaN
# 610972          NaN
# 610973          NaN
# 610974          NaN
# 610975          NaN
#
# [74176 rows x 6 columns]

# %%
zori_metro_long['date'] = zori_metro_long['date'] + pd.offsets.MonthBegin(1)

zori_metro_long
# Out:
#                    name       date         zori      lat       lng  \
# 0         United States 2015-02-01  1197.135014      NaN       NaN
# 81         New York, NY 2015-02-01  2233.141451  40.6943  -73.9249
# 162     Los Angeles, CA 2015-02-01  1809.922576  34.1141 -118.4068
# 243         Chicago, IL 2015-02-01  1400.342984  41.8375  -87.6866
# 324          Dallas, TX 2015-02-01  1095.378833  32.7935  -96.7667
# ...                 ...        ...          ...      ...       ...
# 610971     Portales, NM 2025-03-01   852.638889  34.1754 -103.3565
# 610972   Los Alamos, NM 2025-03-01  2733.333333  35.8927 -106.2862
# 610973  Brownsville, TN 2025-03-01   962.500000  35.5890  -89.2578
# 610974     Atchison, KS 2025-03-01  1025.000000  39.5625  -95.1367
# 610975    Fairfield, IA 2025-03-01   980.000000  41.0064  -91.9667
#
#            pop_2023
# 0       335893238.0
# 81       19498249.0
# 162      12799100.0
# 243       9262825.0
# 324       8100037.0
# ...             ...
# 610971          NaN
# 610972          NaN
# 610973          NaN
# 610974          NaN
# 610975          NaN
#
# [74176 rows x 6 columns]

# %%
# filter for top 50 metros
import json
with open('data/top_metros.json') as f:
    top_metros = json.load(f)

# filter to only the top metros
zori_metro_long = zori_metro_long[zori_metro_long['name'].isin(top_metros)]

# %%
zori_metro_long
# Out:
#                       name       date         zori      lat       lng  \
# 81            New York, NY 2015-02-01  2233.141451  40.6943  -73.9249
# 162        Los Angeles, CA 2015-02-01  1809.922576  34.1141 -118.4068
# 243            Chicago, IL 2015-02-01  1400.342984  41.8375  -87.6866
# 324             Dallas, TX 2015-02-01  1095.378833  32.7935  -96.7667
# 405            Houston, TX 2015-02-01  1217.199895  29.7860  -95.3885
# ...                    ...        ...          ...      ...       ...
# 609775  Salt Lake City, UT 2025-03-01  1662.887724  40.7776 -111.9311
# 609856        Hartford, CT 2025-03-01  1861.878310  41.7661  -72.6834
# 609937         Buffalo, NY 2025-03-01  1331.626117  42.9018  -78.8487
# 610018      Birmingham, AL 2025-03-01  1388.316805  33.5279  -86.7971
# 610180    Grand Rapids, MI 2025-03-01  1623.962106  42.9619  -85.6562
#
#           pop_2023
# 81      19498249.0
# 162     12799100.0
# 243      9262825.0
# 324      8100037.0
# 405      7510253.0
# ...            ...
# 609775   1267864.0
# 609856   1151543.0
# 609937   1155604.0
# 610018   1184290.0
# 610180   1162950.0
#
# [6100 rows x 6 columns]

# %%
# save to csv
zori_metro_long.to_csv('data/zori_metro_long_clean.csv', index=False)

# %% [markdown]
# ## Market heat index

# %%
# Read in market temp
heat_metro_wide = pd.read_csv('data/zillow_temp_wide.csv')
heat_metro_wide

# drop rows with no population value
heat_metro_wide = heat_metro_wide.dropna(subset=['pop_2023'])

# convert pop_2023 to numeric
heat_metro_wide['pop_2023'] = pd.to_numeric(heat_metro_wide['pop_2023'].str.replace(',', ''), errors='coerce')

# sort by population
heat_metro_wide.sort_values(
    by = 'pop_2023',
    ascending = False,
    inplace = True
)

# melt df
heat_metro_long = pd.melt(
    heat_metro_wide,
    id_vars = index_cols,
    value_vars = [col for col in heat_metro_wide.columns if col not in index_cols],
    var_name = "date",
    value_name = "heat"
)

# convert date to datetime 
heat_metro_long['date'] = pd.to_datetime(heat_metro_long['date'])

# rename name column in heat df
heat_metro_long.rename(
    columns={
        "RegionName":"name"
    },
    inplace=True
)

# Merge the two DataFrames
heat_metro_long = heat_metro_long.merge(
    cities[['name', 'lat', 'lng']],  # Select only relevant columns from `cities`
    on='name',
    how='left'
)

heat_metro_long
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2619267285.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   heat_metro_long['date'] = pd.to_datetime(heat_metro_long['date'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[22], line 28
#      19 heat_metro_long = pd.melt(
#      20     heat_metro_wide,
#      21     id_vars = index_cols,
#    (...)
#      24     value_name = "heat"
#      25 )
#      27 # convert date to datetime
# ---> 28 heat_metro_long['date'] = pd.to_datetime(heat_metro_long['date'])
#      30 # rename name column in heat df
#      31 heat_metro_long.rename(
#      32     columns={
#      33         "RegionName":"name"
#      34     },
#      35     inplace=True
#      36 )
#
# File ~/.local/pipx/venvs/jupyterlab/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~/.local/pipx/venvs/jupyterlab/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File ~/.local/pipx/venvs/jupyterlab/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     432 if format is not None and format != "mixed":
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#     438     yearfirst=yearfirst,
#     439     utc=utc,
#     440     errors=errors,
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#     447     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/.local/pipx/venvs/jupyterlab/lib/python3.13/site-packages/pandas/core/arrays/datetimes.py:2398, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2395 # if str-dtype, convert
#    2396 data = np.asarray(data, dtype=np.object_)
# -> 2398 result, tz_parsed = tslib.array_to_datetime(
#    2399     data,
#    2400     errors=errors,
#    2401     utc=utc,
#    2402     dayfirst=dayfirst,
#    2403     yearfirst=yearfirst,
#    2404     creso=abbrev_to_npy_unit(out_unit),
#    2405 )
#    2407 if tz_parsed is not None:
#    2408     # We can take a shortcut since the datetime64 numpy array
#    2409     #  is in UTC
#    2410     return result, tz_parsed
#
# File tslib.pyx:414, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:553, in pandas._libs.tslib.array_to_datetime()
#
# File conversion.pyx:641, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File parsing.pyx:336, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File parsing.pyx:666, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: pop_2023, at position 0

# %%
heat_zori_metro = heat_metro_long.merge(
    zori_metro_long,
    on=[col for col in heat_metro_long.columns if col not in ['heat']],
    suffixes=('_heat', '_zori')
)

heat_zori_metro

# %%
heat_zori_metro.to_csv('data/heat_zori_metro_clean.csv')

# %%
# Step 1: Find the most recent date in the dataset
most_recent_date = heat_zori_metro['date'].max()

# Step 2: Calculate the 'most_recent_heat' and 'most_recent_zori' for each metro area
most_recent_data = heat_zori_metro[heat_zori_metro['date'] == most_recent_date]

# Step 3: Initialize the result DataFrame with 'name' and 'pop_2023' columns
result_df = most_recent_data[['name','pop_2023','lat','lng']].copy()
result_df['most_recent_heat'] = most_recent_data['heat']
result_df['most_recent_zori'] = most_recent_data['zori']
result_df['most_recent_date'] = most_recent_date

# Step 4: Calculate year-over-year percent changes for 'heat' and 'zori'
for years in range(1, 6):  # Loop for 1-year to 5-year changes
    # Calculate the date N years before the most recent date
    previous_date = most_recent_date - pd.DateOffset(years=years)

    # Filter data for the previous date for each metro area
    previous_data = heat_zori_metro[heat_zori_metro['date'] == previous_date]
    previous_data = previous_data.set_index('name')  # Set 'name' as index for easy lookup

    # Calculate percent change for 'heat' and 'zori'
    result_df[f'heat_{years}yc'] = (
        (result_df['most_recent_heat'] - result_df['name'].map(previous_data['heat'])) /
        result_df['name'].map(previous_data['heat'])
    ) 

    result_df[f'zori_{years}yc'] = (
        (result_df['most_recent_zori'] - result_df['name'].map(previous_data['zori'])) /
        result_df['name'].map(previous_data['zori'])
    )

# %%
result_df

# %%
# get rid of the row where name == 'United States'
result_df = result_df[result_df['name'] != 'United States']
result_df

# %%
result_df.to_csv('data/heat_zori_change.csv', index=False)

# %% [markdown]
# ## County-level ZORI

# %%
county_wide_url = "https://files.zillowstatic.com/research/public_csvs/zori/County_zori_uc_sfrcondomfr_sm_month.csv?t=1734717130"

# %%
zori_county_wide = pd.read_csv(county_wide_url)

zori_county_wide
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     county        CA    CA
# 1          139         1         Cook County     county        IL    IL
# 2         1090         2       Harris County     county        TX    TX
# 3         2402         3     Maricopa County     county        AZ    AZ
# 4         2841         4    San Diego County     county        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 1061      2427      2245     McKenzie County     county        ND    ND
# 1062      2618      2270    Archuleta County     county        CO    CO
# 1063       882      2404       Blanco County     county        TX    TX
# 1064      3091      2537  Clear Creek County     county        CO    CO
# 1065      3242      2714      Lexington City     county        VA    VA
#
#                                      Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0       Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1       Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2     Houston-The Woodlands-Sugar Land, TX             48                201
# 3                Phoenix-Mesa-Chandler, AZ              4                 13
# 4       San Diego-Chula Vista-Carlsbad, CA              6                 73
# ...                                    ...            ...                ...
# 1061                                   NaN             38                 53
# 1062                                   NaN              8                  7
# 1063                                   NaN             48                 31
# 1064            Denver-Aurora-Lakewood, CO              8                 19
# 1065                                   NaN             51                678
#
#        2015-01-31  ...   2024-05-31   2024-06-30   2024-07-31   2024-08-31  \
# 0     1764.683373  ...  2826.612800  2837.497395  2849.800647  2854.612371
# 1     1458.893358  ...  2070.155736  2087.897253  2095.028157  2094.593771
# 2     1196.920098  ...  1625.199460  1634.922387  1639.574042  1642.341633
# 3      937.049534  ...  1821.045083  1823.645157  1825.245572  1825.191574
# 4     1678.538777  ...  2987.104258  3007.706622  3020.062465  3022.672173
# ...           ...  ...          ...          ...          ...          ...
# 1061          NaN  ...          NaN          NaN          NaN          NaN
# 1062          NaN  ...          NaN          NaN          NaN          NaN
# 1063          NaN  ...          NaN          NaN          NaN          NaN
# 1064          NaN  ...          NaN          NaN          NaN          NaN
# 1065          NaN  ...          NaN          NaN          NaN          NaN
#
#        2024-09-30   2024-10-31   2024-11-30   2024-12-31   2025-01-31  \
# 0     2860.540364  2858.127749  2856.196155  2849.057216  2874.956519
# 1     2089.090616  2084.874457  2086.485373  2091.522805  2100.817298
# 2     1643.790891  1643.247809  1638.908934  1634.532118  1634.251013
# 3     1824.415478  1814.824385  1805.131597  1797.062770  1799.256444
# 4     3019.724963  3015.070336  3012.296522  3004.142506  3004.973374
# ...           ...          ...          ...          ...          ...
# 1061          NaN          NaN          NaN          NaN  1588.608459
# 1062          NaN          NaN          NaN          NaN          NaN
# 1063          NaN          NaN          NaN          NaN  1292.006558
# 1064          NaN          NaN          NaN          NaN          NaN
# 1065          NaN          NaN          NaN          NaN          NaN
#
#        2025-02-28
# 0     2898.351766
# 1     2118.479524
# 2     1637.503955
# 3     1808.114958
# 4     3011.576644
# ...           ...
# 1061  1542.000000
# 1062  1637.500000
# 1063  1435.000000
# 1064  1725.000000
# 1065   847.500000
#
# [1066 rows x 131 columns]

# %%
import pandas as pd

# %%
city_url="https://files.zillowstatic.com/research/public_csvs/zori/City_zori_uc_sfrcondomfr_sm_month.csv?t=1731500153"

zori_city_wide = pd.read_csv(city_url)

zori_city_wide
# Out:
#       RegionID  SizeRank   RegionName RegionType StateName State  \
# 0         6181         0     New York       city        NY    NY
# 1        12447         1  Los Angeles       city        CA    CA
# 2        39051         2      Houston       city        TX    TX
# 3        17426         3      Chicago       city        IL    IL
# 4         6915         4  San Antonio       city        TX    TX
# ...        ...       ...          ...        ...       ...   ...
# 3302     16007     20418    Surf City       city        NC    NC
# 3303      6459     21336  Pendergrass       city        GA    GA
# 3304    124999     22408    Lake Hart       city        FL    FL
# 3305     47500     22616   Sagaponack       city        NY    NY
# 3306    860532     28607  Fort Mohave       city        AZ    AZ
#
#                                       Metro          CountyName   2015-01-31  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2519.633872
# 1        Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  1829.491393
# 2      Houston-The Woodlands-Sugar Land, TX       Harris County  1192.772833
# 3        Chicago-Naperville-Elgin, IL-IN-WI         Cook County  1525.898035
# 4             San Antonio-New Braunfels, TX        Bexar County   994.108337
# ...                                     ...                 ...          ...
# 3302                         Wilmington, NC       Pender County          NaN
# 3303                          Jefferson, GA      Jackson County          NaN
# 3304          Orlando-Kissimmee-Sanford, FL       Orange County          NaN
# 3305  New York-Newark-Jersey City, NY-NJ-PA      Suffolk County          NaN
# 3306           Lake Havasu City-Kingman, AZ       Mohave County          NaN
#
#        2015-02-28  ...   2024-05-31   2024-06-30   2024-07-31   2024-08-31  \
# 0     2532.526220  ...  3471.695054  3507.169000  3527.537949  3530.370179
# 1     1844.612499  ...  2817.809080  2828.720362  2840.709137  2846.201537
# 2     1196.480207  ...  1588.762190  1599.384752  1603.832709  1605.936383
# 3     1534.847198  ...  2135.297477  2154.853317  2161.770567  2157.918278
# 4      997.530557  ...  1434.863066  1437.503190  1438.405606  1436.567604
# ...           ...  ...          ...          ...          ...          ...
# 3302          NaN  ...          NaN          NaN          NaN          NaN
# 3303          NaN  ...          NaN          NaN          NaN  1991.678610
# 3304          NaN  ...  2499.434958  2492.957795  2562.350062  2613.727060
# 3305          NaN  ...          NaN          NaN          NaN          NaN
# 3306          NaN  ...          NaN          NaN          NaN          NaN
#
#        2024-09-30   2024-10-31   2024-11-30   2024-12-31     2025-01-31  \
# 0     3514.693097  3492.480172  3468.327426  3453.597591    3458.924544
# 1     2849.944139  2845.777630  2842.472672  2834.889984    2861.149444
# 2     1606.777190  1606.008116  1601.293595  1596.883827    1595.994789
# 3     2149.395505  2139.618246  2138.892360  2141.078458    2151.641380
# 4     1430.043966  1414.588476  1405.290319  1399.937448    1405.874726
# ...           ...          ...          ...          ...            ...
# 3302          NaN          NaN          NaN          NaN    1751.329577
# 3303  2005.425210  1999.533909  1987.517792  2005.645164    2007.414753
# 3304  2609.188756  2514.304695  2482.493642  2481.646240    2483.124054
# 3305          NaN          NaN          NaN          NaN  102629.095543
# 3306          NaN          NaN          NaN          NaN    1975.521822
#
#          2025-02-28
# 0       3488.735636
# 1       2884.217593
# 2       1598.473864
# 3       2172.130290
# 4       1412.425356
# ...             ...
# 3302    1795.000000
# 3303    2005.000000
# 3304    2492.260317
# 3305  102500.000000
# 3306    1975.000000
#
# [3307 rows x 130 columns]

# %% [markdown]
# ## population centroids

# %%
import pandas as pd

# %%
county_centroids_url = "https://www2.census.gov/geo/docs/reference/cenpop2020/county/CenPop2020_Mean_CO.txt"

county_centroids = pd.read_csv(county_centroids_url)

county_centroids.to_csv('data/county_centroids.csv', index=False)

# %%
county_centroids.dtypes
# Out:
# STATEFP         int64
# COUNTYFP        int64
# COUNAME        object
# STNAME         object
# POPULATION      int64
# LATITUDE      float64
# LONGITUDE     float64
# dtype: object

# %%
county_centroids
# Out:
#       STATEFP  COUNTYFP    COUNAME       STNAME  POPULATION   LATITUDE  \
# 0           1         1    Autauga      Alabama       58805  32.500194
# 1           1         3    Baldwin      Alabama      231767  30.537396
# 2           1         5    Barbour      Alabama       25223  31.843981
# 3           1         7       Bibb      Alabama       22293  33.032236
# 4           1         9     Blount      Alabama       59134  33.954604
# ...       ...       ...        ...          ...         ...        ...
# 3216       72       145  Vega Baja  Puerto Rico       54414  18.439692
# 3217       72       147    Vieques  Puerto Rico        8249  18.134221
# 3218       72       149   Villalba  Puerto Rico       22093  18.123806
# 3219       72       151    Yabucoa  Puerto Rico       30426  18.068957
# 3220       72       153      Yauco  Puerto Rico       34172  18.043328
#
#       LONGITUDE
# 0    -86.487813
# 1    -87.761478
# 2    -85.301306
# 3    -87.136826
# 4    -86.592667
# ...         ...
# 3216 -66.399082
# 3217 -65.448953
# 3218 -66.486557
# 3219 -65.885852
# 3220 -66.859541
#
# [3221 rows x 7 columns]

# %%
county_centroids[county_centroids['STNAME'] == 'Connecticut']
# Out:
#      STATEFP  COUNTYFP     COUNAME       STNAME  POPULATION   LATITUDE  \
# 309        9         1   Fairfield  Connecticut      957419  41.206021
# 310        9         3    Hartford  Connecticut      899498  41.761165
# 311        9         5  Litchfield  Connecticut      185186  41.726958
# 312        9         7   Middlesex  Connecticut      164245  41.479018
# 313        9         9   New Haven  Connecticut      864835  41.396593
# 314        9        11  New London  Connecticut      268555  41.443271
# 315        9        13     Tolland  Connecticut      149788  41.842288
# 316        9        15     Windham  Connecticut      116418  41.805080
#
#      LONGITUDE
# 309 -73.367214
# 310 -72.717868
# 311 -73.190432
# 312 -72.571631
# 313 -72.942327
# 314 -72.097543
# 315 -72.372969
# 316 -71.993508

# %%
# create fips column
county_centroids['fips'] = county_centroids['STATEFP'] * 1000 + county_centroids['COUNTYFP']

county_centroids
# Out:
#       STATEFP  COUNTYFP    COUNAME       STNAME  POPULATION   LATITUDE  \
# 0           1         1    Autauga      Alabama       58805  32.500194
# 1           1         3    Baldwin      Alabama      231767  30.537396
# 2           1         5    Barbour      Alabama       25223  31.843981
# 3           1         7       Bibb      Alabama       22293  33.032236
# 4           1         9     Blount      Alabama       59134  33.954604
# ...       ...       ...        ...          ...         ...        ...
# 3216       72       145  Vega Baja  Puerto Rico       54414  18.439692
# 3217       72       147    Vieques  Puerto Rico        8249  18.134221
# 3218       72       149   Villalba  Puerto Rico       22093  18.123806
# 3219       72       151    Yabucoa  Puerto Rico       30426  18.068957
# 3220       72       153      Yauco  Puerto Rico       34172  18.043328
#
#       LONGITUDE   fips
# 0    -86.487813   1001
# 1    -87.761478   1003
# 2    -85.301306   1005
# 3    -87.136826   1007
# 4    -86.592667   1009
# ...         ...    ...
# 3216 -66.399082  72145
# 3217 -65.448953  72147
# 3218 -66.486557  72149
# 3219 -65.885852  72151
# 3220 -66.859541  72153
#
# [3221 rows x 8 columns]

# %%
county_centroids[county_centroids['STNAME'] == 'Connecticut']
# Out:
#      STATEFP  COUNTYFP     COUNAME       STNAME  POPULATION   LATITUDE  \
# 309        9         1   Fairfield  Connecticut      957419  41.206021
# 310        9         3    Hartford  Connecticut      899498  41.761165
# 311        9         5  Litchfield  Connecticut      185186  41.726958
# 312        9         7   Middlesex  Connecticut      164245  41.479018
# 313        9         9   New Haven  Connecticut      864835  41.396593
# 314        9        11  New London  Connecticut      268555  41.443271
# 315        9        13     Tolland  Connecticut      149788  41.842288
# 316        9        15     Windham  Connecticut      116418  41.805080
#
#      LONGITUDE  fips
# 309 -73.367214  9001
# 310 -72.717868  9003
# 311 -73.190432  9005
# 312 -72.571631  9007
# 313 -72.942327  9009
# 314 -72.097543  9011
# 315 -72.372969  9013
# 316 -71.993508  9015

# %%
# read in population data
pop_est = pd.read_excel('data/PopulationEstimates.xlsx', skiprows=4,)

pop_est
# Out:
#       FIPStxt State            Area_Name  Rural_Urban_Continuum_Code_2013  \
# 0           0    US        United States                              NaN
# 1        1000    AL              Alabama                              NaN
# 2        1001    AL       Autauga County                              2.0
# 3        1003    AL       Baldwin County                              3.0
# 4        1005    AL       Barbour County                              6.0
# ...       ...   ...                  ...                              ...
# 3278    72145    PR  Vega Baja Municipio                              1.0
# 3279    72147    PR    Vieques Municipio                              7.0
# 3280    72149    PR   Villalba Municipio                              2.0
# 3281    72151    PR    Yabucoa Municipio                              1.0
# 3282    72153    PR      Yauco Municipio                              2.0
#
#       Rural_Urban_Continuum_Code_2023  Urban_Influence_2013  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 2.0                   2.0
# 3                                 3.0                   2.0
# 4                                 6.0                   6.0
# ...                               ...                   ...
# 3278                              1.0                   1.0
# 3279                              6.0                  12.0
# 3280                              2.0                   2.0
# 3281                              1.0                   1.0
# 3282                              2.0                   2.0
#
#       Economic_typology_2015  CENSUS_2020_POP  ESTIMATES_BASE_2020  \
# 0                        NaN      331449281.0          331464948.0
# 1                        NaN        5024279.0            5024294.0
# 2                        0.0          58805.0              58809.0
# 3                        5.0         231767.0             231768.0
# 4                        3.0          25223.0              25229.0
# ...                      ...              ...                  ...
# 3278                     NaN          54414.0              54414.0
# 3279                     NaN           8249.0               8249.0
# 3280                     NaN          22093.0              22093.0
# 3281                     NaN          30426.0              30426.0
# 3282                     NaN          34172.0              34172.0
#
#       POP_ESTIMATE_2020  ...  R_NATURAL_CHG_2023  R_INTERNATIONAL_MIG_2021  \
# 0           331526933.0  ...                 1.5                       1.1
# 1             5031864.0  ...                -0.3                       0.4
# 2               58915.0  ...                 1.5                       0.3
# 3              233227.0  ...                -0.4                       0.4
# 4               24969.0  ...                -3.4                       0.0
# ...                 ...  ...                 ...                       ...
# 3278            54357.0  ...                 NaN                       NaN
# 3279             8236.0  ...                 NaN                       NaN
# 3280            22041.0  ...                 NaN                       NaN
# 3281            30329.0  ...                 NaN                       NaN
# 3282            34048.0  ...                 NaN                       NaN
#
#       R_INTERNATIONAL_MIG_2022  R_INTERNATIONAL_MIG_2023  R_DOMESTIC_MIG_2021  \
# 0                          3.0                       3.4                  0.0
# 1                          0.9                       1.1                  5.5
# 2                          0.4                       0.6                  4.1
# 3                          1.0                       1.2                 29.5
# 4                          0.1                       0.5                -12.6
# ...                        ...                       ...                  ...
# 3278                       NaN                       NaN                  NaN
# 3279                       NaN                       NaN                  NaN
# 3280                       NaN                       NaN                  NaN
# 3281                       NaN                       NaN                  NaN
# 3282                       NaN                       NaN                  NaN
#
#       R_DOMESTIC_MIG_2022  R_DOMESTIC_MIG_2023  R_NET_MIG_2021  \
# 0                     0.0                  0.0             1.1
# 1                     5.6                  6.0             5.9
# 2                     8.5                  8.2             4.4
# 3                    29.0                 27.2            29.9
# 4                     9.6                 -1.8           -12.6
# ...                   ...                  ...             ...
# 3278                  NaN                  NaN             NaN
# 3279                  NaN                  NaN             NaN
# 3280                  NaN                  NaN             NaN
# 3281                  NaN                  NaN             NaN
# 3282                  NaN                  NaN             NaN
#
#       R_NET_MIG_2022  R_NET_MIG_2023
# 0                3.0             3.4
# 1                6.5             7.1
# 2                8.9             8.7
# 3               30.0            28.4
# 4                9.7            -1.3
# ...              ...             ...
# 3278             NaN             NaN
# 3279             NaN             NaN
# 3280             NaN             NaN
# 3281             NaN             NaN
# 3282             NaN             NaN
#
# [3283 rows x 68 columns]

# %%
pop_est[pop_est['State'] == 'CT']
# Out:
#      FIPStxt State                                       Area_Name  \
# 316     9000    CT                                     Connecticut
# 317     9001    CT                                Fairfield County
# 318     9003    CT                                 Hartford County
# 319     9005    CT                               Litchfield County
# 320     9007    CT                                Middlesex County
# 321     9009    CT                                New Haven County
# 322     9011    CT                               New London County
# 323     9013    CT                                  Tolland County
# 324     9015    CT                                  Windham County
# 325     9110    CT                         Capitol Planning Region
# 326     9120    CT              Greater Bridgeport Planning Region
# 327     9130    CT  Lower Connecticut River Valley Planning Region
# 328     9140    CT                Naugatuck Valley Planning Region
# 329     9150    CT        Northeastern Connecticut Planning Region
# 330     9160    CT                 Northwest Hills Planning Region
# 331     9170    CT       South Central Connecticut Planning Region
# 332     9180    CT        Southeastern Connecticut Planning Region
# 333     9190    CT             Western Connecticut Planning Region
#
#      Rural_Urban_Continuum_Code_2013  Rural_Urban_Continuum_Code_2023  \
# 316                              NaN                              NaN
# 317                              2.0                              NaN
# 318                              1.0                              NaN
# 319                              4.0                              NaN
# 320                              1.0                              NaN
# 321                              2.0                              NaN
# 322                              2.0                              NaN
# 323                              1.0                              NaN
# 324                              2.0                              NaN
# 325                              NaN                              1.0
# 326                              NaN                              2.0
# 327                              NaN                              1.0
# 328                              NaN                              2.0
# 329                              NaN                              4.0
# 330                              NaN                              4.0
# 331                              NaN                              2.0
# 332                              NaN                              2.0
# 333                              NaN                              2.0
#
#      Urban_Influence_2013  Economic_typology_2015  CENSUS_2020_POP  \
# 316                   NaN                     NaN        3605944.0
# 317                   2.0                     0.0         957419.0
# 318                   1.0                     0.0         899498.0
# 319                   3.0                     0.0         185186.0
# 320                   1.0                     0.0         164245.0
# 321                   2.0                     0.0         864835.0
# 322                   2.0                     0.0         268555.0
# 323                   1.0                     4.0         149788.0
# 324                   2.0                     0.0         116418.0
# 325                   NaN                     NaN              NaN
# 326                   NaN                     NaN              NaN
# 327                   NaN                     NaN              NaN
# 328                   NaN                     NaN              NaN
# 329                   NaN                     NaN              NaN
# 330                   NaN                     NaN              NaN
# 331                   NaN                     NaN              NaN
# 332                   NaN                     NaN              NaN
# 333                   NaN                     NaN              NaN
#
#      ESTIMATES_BASE_2020  POP_ESTIMATE_2020  ...  R_NATURAL_CHG_2023  \
# 316            3605912.0          3577586.0  ...                 0.6
# 317                  NaN                NaN  ...                 NaN
# 318                  NaN                NaN  ...                 NaN
# 319                  NaN                NaN  ...                 NaN
# 320                  NaN                NaN  ...                 NaN
# 321                  NaN                NaN  ...                 NaN
# 322                  NaN                NaN  ...                 NaN
# 323                  NaN                NaN  ...                 NaN
# 324                  NaN                NaN  ...                 NaN
# 325             976275.0           962436.0  ...                 0.3
# 326             325774.0           324387.0  ...                 3.0
# 327             174225.0           173268.0  ...                -1.7
# 328             450435.0           449285.0  ...                 0.4
# 329              95336.0            95222.0  ...                -1.9
# 330             112465.0           112202.0  ...                -2.4
# 331             570455.0           564076.0  ...                 0.4
# 332             280428.0           278342.0  ...                -1.3
# 333             620519.0           618368.0  ...                 2.6
#
#      R_INTERNATIONAL_MIG_2021  R_INTERNATIONAL_MIG_2022  \
# 316                       1.7                       4.3
# 317                       NaN                       NaN
# 318                       NaN                       NaN
# 319                       NaN                       NaN
# 320                       NaN                       NaN
# 321                       NaN                       NaN
# 322                       NaN                       NaN
# 323                       NaN                       NaN
# 324                       NaN                       NaN
# 325                       1.8                       4.6
# 326                       2.8                       6.5
# 327                       0.7                       2.2
# 328                       1.1                       3.2
# 329                       0.3                       1.1
# 330                       0.6                       2.0
# 331                       1.8                       3.9
# 332                       1.2                       2.1
# 333                       2.5                       6.5
#
#      R_INTERNATIONAL_MIG_2023  R_DOMESTIC_MIG_2021  R_DOMESTIC_MIG_2022  \
# 316                       4.2                  5.3                 -2.8
# 317                       NaN                  NaN                  NaN
# 318                       NaN                  NaN                  NaN
# 319                       NaN                  NaN                  NaN
# 320                       NaN                  NaN                  NaN
# 321                       NaN                  NaN                  NaN
# 322                       NaN                  NaN                  NaN
# 323                       NaN                  NaN                  NaN
# 324                       NaN                  NaN                  NaN
# 325                       4.5                  6.2                 -2.0
# 326                       6.3                  1.7                 -8.0
# 327                       2.1                 14.3                  3.5
# 328                       3.0                  5.4                  0.4
# 329                       1.0                  6.2                  6.7
# 330                       1.9                  8.8                  4.2
# 331                       4.0                  6.2                 -3.5
# 332                       2.1                  1.9                  1.5
# 333                       6.4                  3.1                 -9.5
#
#      R_DOMESTIC_MIG_2023  R_NET_MIG_2021  R_NET_MIG_2022  R_NET_MIG_2023
# 316                 -2.5             7.0             1.5             1.7
# 317                  NaN             NaN             NaN             NaN
# 318                  NaN             NaN             NaN             NaN
# 319                  NaN             NaN             NaN             NaN
# 320                  NaN             NaN             NaN             NaN
# 321                  NaN             NaN             NaN             NaN
# 322                  NaN             NaN             NaN             NaN
# 323                  NaN             NaN             NaN             NaN
# 324                  NaN             NaN             NaN             NaN
# 325                 -1.4             7.9             2.6             3.1
# 326                 -7.8             4.5            -1.5            -1.5
# 327                  0.9            15.0             5.7             3.0
# 328                  2.2             6.6             3.6             5.2
# 329                  6.5             6.5             7.7             7.6
# 330                  2.2             9.5             6.2             4.1
# 331                 -4.8             8.0             0.5            -0.8
# 332                  0.6             3.2             3.6             2.6
# 333                 -7.4             5.6            -3.1            -1.0
#
# [18 rows x 68 columns]

# %%
pop_2023 = pop_est[['FIPStxt', 'POP_ESTIMATE_2023']]
pop_2023
# Out:
#       FIPStxt  POP_ESTIMATE_2023
# 0           0          334914895
# 1        1000            5108468
# 2        1001              60342
# 3        1003             253507
# 4        1005              24585
# ...       ...                ...
# 3278    72145              53527
# 3279    72147               7999
# 3280    72149              21285
# 3281    72151              28897
# 3282    72153              32406
#
# [3283 rows x 2 columns]

# %%
# unified col names
pop_2023.columns = ['fips', 'pop_2023']

# %%
# merge county centroids with population data
county_centroids = county_centroids.merge(
    pop_2023,
    on='fips',
    how='left'
)

# drop unnecessary columns
county_centroids.drop(
    columns=['STATEFP', 'COUNTYFP', 'POPULATION', 'COUNAME', 'STNAME'],
    inplace=True
)

county_centroids
# Out:
#        LATITUDE  LONGITUDE   fips  pop_2023
# 0     32.500194 -86.487813   1001     60342
# 1     30.537396 -87.761478   1003    253507
# 2     31.843981 -85.301306   1005     24585
# 3     33.032236 -87.136826   1007     21868
# 4     33.954604 -86.592667   1009     59816
# ...         ...        ...    ...       ...
# 3216  18.439692 -66.399082  72145     53527
# 3217  18.134221 -65.448953  72147      7999
# 3218  18.123806 -66.486557  72149     21285
# 3219  18.068957 -65.885852  72151     28897
# 3220  18.043328 -66.859541  72153     32406
#
# [3221 rows x 4 columns]

# %%
# rename columns
county_centroids.columns = ['lat', 'lng', 'fips', 'pop_2023']

county_centroids
# Out:
#             lat        lng   fips  pop_2023
# 0     32.500194 -86.487813   1001     60342
# 1     30.537396 -87.761478   1003    253507
# 2     31.843981 -85.301306   1005     24585
# 3     33.032236 -87.136826   1007     21868
# 4     33.954604 -86.592667   1009     59816
# ...         ...        ...    ...       ...
# 3216  18.439692 -66.399082  72145     53527
# 3217  18.134221 -65.448953  72147      7999
# 3218  18.123806 -66.486557  72149     21285
# 3219  18.068957 -65.885852  72151     28897
# 3220  18.043328 -66.859541  72153     32406
#
# [3221 rows x 4 columns]

# %%
# form a fips col for zori_county_wide
zori_county_wide['fips'] = zori_county_wide['StateCodeFIPS'] * 1000 + zori_county_wide['MunicipalCodeFIPS']

# form a name col for zori_county_wide
zori_county_wide['name'] = zori_county_wide['RegionName'] + ', ' + zori_county_wide['State']

zori_county_wide
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     county        CA    CA
# 1          139         1         Cook County     county        IL    IL
# 2         1090         2       Harris County     county        TX    TX
# 3         2402         3     Maricopa County     county        AZ    AZ
# 4         2841         4    San Diego County     county        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 1061      2427      2245     McKenzie County     county        ND    ND
# 1062      2618      2270    Archuleta County     county        CO    CO
# 1063       882      2404       Blanco County     county        TX    TX
# 1064      3091      2537  Clear Creek County     county        CO    CO
# 1065      3242      2714      Lexington City     county        VA    VA
#
#                                      Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0       Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1       Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2     Houston-The Woodlands-Sugar Land, TX             48                201
# 3                Phoenix-Mesa-Chandler, AZ              4                 13
# 4       San Diego-Chula Vista-Carlsbad, CA              6                 73
# ...                                    ...            ...                ...
# 1061                                   NaN             38                 53
# 1062                                   NaN              8                  7
# 1063                                   NaN             48                 31
# 1064            Denver-Aurora-Lakewood, CO              8                 19
# 1065                                   NaN             51                678
#
#        2015-01-31  ...   2024-07-31   2024-08-31   2024-09-30   2024-10-31  \
# 0     1764.683373  ...  2849.800647  2854.612371  2860.540364  2858.127749
# 1     1458.893358  ...  2095.028157  2094.593771  2089.090616  2084.874457
# 2     1196.920098  ...  1639.574042  1642.341633  1643.790891  1643.247809
# 3      937.049534  ...  1825.245572  1825.191574  1824.415478  1814.824385
# 4     1678.538777  ...  3020.062465  3022.672173  3019.724963  3015.070336
# ...           ...  ...          ...          ...          ...          ...
# 1061          NaN  ...          NaN          NaN          NaN          NaN
# 1062          NaN  ...          NaN          NaN          NaN          NaN
# 1063          NaN  ...          NaN          NaN          NaN          NaN
# 1064          NaN  ...          NaN          NaN          NaN          NaN
# 1065          NaN  ...          NaN          NaN          NaN          NaN
#
#        2024-11-30   2024-12-31   2025-01-31   2025-02-28   fips  \
# 0     2856.196155  2849.057216  2874.956519  2898.351766   6037
# 1     2086.485373  2091.522805  2100.817298  2118.479524  17031
# 2     1638.908934  1634.532118  1634.251013  1637.503955  48201
# 3     1805.131597  1797.062770  1799.256444  1808.114958   4013
# 4     3012.296522  3004.142506  3004.973374  3011.576644   6073
# ...           ...          ...          ...          ...    ...
# 1061          NaN          NaN  1588.608459  1542.000000  38053
# 1062          NaN          NaN          NaN  1637.500000   8007
# 1063          NaN          NaN  1292.006558  1435.000000  48031
# 1064          NaN          NaN          NaN  1725.000000   8019
# 1065          NaN          NaN          NaN   847.500000  51678
#
#                         name
# 0     Los Angeles County, CA
# 1            Cook County, IL
# 2          Harris County, TX
# 3        Maricopa County, AZ
# 4       San Diego County, CA
# ...                      ...
# 1061     McKenzie County, ND
# 1062    Archuleta County, CO
# 1063       Blanco County, TX
# 1064  Clear Creek County, CO
# 1065      Lexington City, VA
#
# [1066 rows x 133 columns]

# %%
# merge with population centroids
zori_county_wide = zori_county_wide.merge(
    county_centroids,
    on = 'fips',
    how='left'
)

zori_county_wide
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     county        CA    CA
# 1          139         1         Cook County     county        IL    IL
# 2         1090         2       Harris County     county        TX    TX
# 3         2402         3     Maricopa County     county        AZ    AZ
# 4         2841         4    San Diego County     county        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 1061      2427      2245     McKenzie County     county        ND    ND
# 1062      2618      2270    Archuleta County     county        CO    CO
# 1063       882      2404       Blanco County     county        TX    TX
# 1064      3091      2537  Clear Creek County     county        CO    CO
# 1065      3242      2714      Lexington City     county        VA    VA
#
#                                      Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0       Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1       Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2     Houston-The Woodlands-Sugar Land, TX             48                201
# 3                Phoenix-Mesa-Chandler, AZ              4                 13
# 4       San Diego-Chula Vista-Carlsbad, CA              6                 73
# ...                                    ...            ...                ...
# 1061                                   NaN             38                 53
# 1062                                   NaN              8                  7
# 1063                                   NaN             48                 31
# 1064            Denver-Aurora-Lakewood, CO              8                 19
# 1065                                   NaN             51                678
#
#        2015-01-31  ...   2024-10-31   2024-11-30   2024-12-31   2025-01-31  \
# 0     1764.683373  ...  2858.127749  2856.196155  2849.057216  2874.956519
# 1     1458.893358  ...  2084.874457  2086.485373  2091.522805  2100.817298
# 2     1196.920098  ...  1643.247809  1638.908934  1634.532118  1634.251013
# 3      937.049534  ...  1814.824385  1805.131597  1797.062770  1799.256444
# 4     1678.538777  ...  3015.070336  3012.296522  3004.142506  3004.973374
# ...           ...  ...          ...          ...          ...          ...
# 1061          NaN  ...          NaN          NaN          NaN  1588.608459
# 1062          NaN  ...          NaN          NaN          NaN          NaN
# 1063          NaN  ...          NaN          NaN          NaN  1292.006558
# 1064          NaN  ...          NaN          NaN          NaN          NaN
# 1065          NaN  ...          NaN          NaN          NaN          NaN
#
#        2025-02-28   fips                    name        lat         lng  \
# 0     2898.351766   6037  Los Angeles County, CA  34.067886 -118.245990
# 1     2118.479524  17031         Cook County, IL  41.869515  -87.757998
# 2     1637.503955  48201       Harris County, TX  29.816889  -95.425716
# 3     1808.114958   4013     Maricopa County, AZ  33.490147 -112.044016
# 4     3011.576644   6073    San Diego County, CA  32.884418 -117.112348
# ...           ...    ...                     ...        ...         ...
# 1061  1542.000000  38053     McKenzie County, ND  47.815379 -103.249949
# 1062  1637.500000   8007    Archuleta County, CO  37.240274 -107.089808
# 1063  1435.000000  48031       Blanco County, TX  30.177148  -98.392080
# 1064  1725.000000   8019  Clear Creek County, CO  39.713458 -105.532527
# 1065   847.500000  51678      Lexington City, VA  37.784392  -79.443722
#
#       pop_2023
# 0      9663345
# 1      5087072
# 2      4835125
# 3      4585871
# 4      3269973
# ...        ...
# 1061     14252
# 1062     14189
# 1063     13048
# 1064      9147
# 1065      7528
#
# [1066 rows x 136 columns]

# %%
# create list of index cols

index_cols = ['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
       'State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS', 'fips', 'name', 'lat', 'lng', 'pop_2023']

# %%
# melt
zori_county_long = pd.melt(
    zori_county_wide,
    id_vars = index_cols,
    value_vars = [col for col in zori_county_wide.columns if col not in index_cols],
    var_name = "date",
    value_name = "zori"
)

zori_county_long
# Out:
#         RegionID  SizeRank          RegionName RegionType StateName State  \
# 0           3101         0  Los Angeles County     county        CA    CA
# 1            139         1         Cook County     county        IL    IL
# 2           1090         2       Harris County     county        TX    TX
# 3           2402         3     Maricopa County     county        AZ    AZ
# 4           2841         4    San Diego County     county        CA    CA
# ...          ...       ...                 ...        ...       ...   ...
# 130047      2427      2245     McKenzie County     county        ND    ND
# 130048      2618      2270    Archuleta County     county        CO    CO
# 130049       882      2404       Blanco County     county        TX    TX
# 130050      3091      2537  Clear Creek County     county        CO    CO
# 130051      3242      2714      Lexington City     county        VA    VA
#
#                                        Metro  StateCodeFIPS  \
# 0         Los Angeles-Long Beach-Anaheim, CA              6
# 1         Chicago-Naperville-Elgin, IL-IN-WI             17
# 2       Houston-The Woodlands-Sugar Land, TX             48
# 3                  Phoenix-Mesa-Chandler, AZ              4
# 4         San Diego-Chula Vista-Carlsbad, CA              6
# ...                                      ...            ...
# 130047                                   NaN             38
# 130048                                   NaN              8
# 130049                                   NaN             48
# 130050            Denver-Aurora-Lakewood, CO              8
# 130051                                   NaN             51
#
#         MunicipalCodeFIPS   fips                    name        lat  \
# 0                      37   6037  Los Angeles County, CA  34.067886
# 1                      31  17031         Cook County, IL  41.869515
# 2                     201  48201       Harris County, TX  29.816889
# 3                      13   4013     Maricopa County, AZ  33.490147
# 4                      73   6073    San Diego County, CA  32.884418
# ...                   ...    ...                     ...        ...
# 130047                 53  38053     McKenzie County, ND  47.815379
# 130048                  7   8007    Archuleta County, CO  37.240274
# 130049                 31  48031       Blanco County, TX  30.177148
# 130050                 19   8019  Clear Creek County, CO  39.713458
# 130051                678  51678      Lexington City, VA  37.784392
#
#                lng  pop_2023        date         zori
# 0      -118.245990   9663345  2015-01-31  1764.683373
# 1       -87.757998   5087072  2015-01-31  1458.893358
# 2       -95.425716   4835125  2015-01-31  1196.920098
# 3      -112.044016   4585871  2015-01-31   937.049534
# 4      -117.112348   3269973  2015-01-31  1678.538777
# ...            ...       ...         ...          ...
# 130047 -103.249949     14252  2025-02-28  1542.000000
# 130048 -107.089808     14189  2025-02-28  1637.500000
# 130049  -98.392080     13048  2025-02-28  1435.000000
# 130050 -105.532527      9147  2025-02-28  1725.000000
# 130051  -79.443722      7528  2025-02-28   847.500000
#
# [130052 rows x 16 columns]

# %%
# keep only necessary cols
zori_county_long_clean = zori_county_long[['name','RegionType', 'fips', 'lat', 'lng', 'pop_2023', 'date', 'zori']]

# rename RegionType to type  
zori_county_long_clean.rename(
    columns={'RegionType':'type'},
    inplace=True
)

zori_county_long_clean
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/3989074384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean.rename(
#                           name    type   fips        lat         lng  \
# 0       Los Angeles County, CA  county   6037  34.067886 -118.245990
# 1              Cook County, IL  county  17031  41.869515  -87.757998
# 2            Harris County, TX  county  48201  29.816889  -95.425716
# 3          Maricopa County, AZ  county   4013  33.490147 -112.044016
# 4         San Diego County, CA  county   6073  32.884418 -117.112348
# ...                        ...     ...    ...        ...         ...
# 130047     McKenzie County, ND  county  38053  47.815379 -103.249949
# 130048    Archuleta County, CO  county   8007  37.240274 -107.089808
# 130049       Blanco County, TX  county  48031  30.177148  -98.392080
# 130050  Clear Creek County, CO  county   8019  39.713458 -105.532527
# 130051      Lexington City, VA  county  51678  37.784392  -79.443722
#
#         pop_2023        date         zori
# 0        9663345  2015-01-31  1764.683373
# 1        5087072  2015-01-31  1458.893358
# 2        4835125  2015-01-31  1196.920098
# 3        4585871  2015-01-31   937.049534
# 4        3269973  2015-01-31  1678.538777
# ...          ...         ...          ...
# 130047     14252  2025-02-28  1542.000000
# 130048     14189  2025-02-28  1637.500000
# 130049     13048  2025-02-28  1435.000000
# 130050      9147  2025-02-28  1725.000000
# 130051      7528  2025-02-28   847.500000
#
# [130052 rows x 8 columns]

# %%
# convert date to datetime
zori_county_long_clean['date'] = pd.to_datetime(zori_county_long_clean['date'])

zori_county_long_clean.dtypes
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/425820618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean['date'] = pd.to_datetime(zori_county_long_clean['date'])
# name                object
# type                object
# fips                 int64
# lat                float64
# lng                float64
# pop_2023             int64
# date        datetime64[ns]
# zori               float64
# dtype: object

# %%
zori_county_long_clean
# Out:
#                           name    type   fips        lat         lng  \
# 0       Los Angeles County, CA  county   6037  34.067886 -118.245990
# 1              Cook County, IL  county  17031  41.869515  -87.757998
# 2            Harris County, TX  county  48201  29.816889  -95.425716
# 3          Maricopa County, AZ  county   4013  33.490147 -112.044016
# 4         San Diego County, CA  county   6073  32.884418 -117.112348
# ...                        ...     ...    ...        ...         ...
# 130047     McKenzie County, ND  county  38053  47.815379 -103.249949
# 130048    Archuleta County, CO  county   8007  37.240274 -107.089808
# 130049       Blanco County, TX  county  48031  30.177148  -98.392080
# 130050  Clear Creek County, CO  county   8019  39.713458 -105.532527
# 130051      Lexington City, VA  county  51678  37.784392  -79.443722
#
#         pop_2023       date         zori
# 0        9663345 2015-01-31  1764.683373
# 1        5087072 2015-01-31  1458.893358
# 2        4835125 2015-01-31  1196.920098
# 3        4585871 2015-01-31   937.049534
# 4        3269973 2015-01-31  1678.538777
# ...          ...        ...          ...
# 130047     14252 2025-02-28  1542.000000
# 130048     14189 2025-02-28  1637.500000
# 130049     13048 2025-02-28  1435.000000
# 130050      9147 2025-02-28  1725.000000
# 130051      7528 2025-02-28   847.500000
#
# [130052 rows x 8 columns]

# %%
# create 1-5 year percent change columns
for years in range(1, 6):
    zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years) 

zori_county_long_clean
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/2798189863.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_long_clean[f'zori_{years}yc'] = zori_county_long_clean.groupby('name')['zori'].pct_change(12 * years)
#                           name    type   fips        lat         lng  \
# 0       Los Angeles County, CA  county   6037  34.067886 -118.245990
# 1              Cook County, IL  county  17031  41.869515  -87.757998
# 2            Harris County, TX  county  48201  29.816889  -95.425716
# 3          Maricopa County, AZ  county   4013  33.490147 -112.044016
# 4         San Diego County, CA  county   6073  32.884418 -117.112348
# ...                        ...     ...    ...        ...         ...
# 130047     McKenzie County, ND  county  38053  47.815379 -103.249949
# 130048    Archuleta County, CO  county   8007  37.240274 -107.089808
# 130049       Blanco County, TX  county  48031  30.177148  -98.392080
# 130050  Clear Creek County, CO  county   8019  39.713458 -105.532527
# 130051      Lexington City, VA  county  51678  37.784392  -79.443722
#
#         pop_2023       date         zori  zori_1yc  zori_2yc  zori_3yc  \
# 0        9663345 2015-01-31  1764.683373       NaN       NaN       NaN
# 1        5087072 2015-01-31  1458.893358       NaN       NaN       NaN
# 2        4835125 2015-01-31  1196.920098       NaN       NaN       NaN
# 3        4585871 2015-01-31   937.049534       NaN       NaN       NaN
# 4        3269973 2015-01-31  1678.538777       NaN       NaN       NaN
# ...          ...        ...          ...       ...       ...       ...
# 130047     14252 2025-02-28  1542.000000       NaN       NaN       NaN
# 130048     14189 2025-02-28  1637.500000       NaN       NaN       NaN
# 130049     13048 2025-02-28  1435.000000       NaN       NaN       NaN
# 130050      9147 2025-02-28  1725.000000       NaN       NaN       NaN
# 130051      7528 2025-02-28   847.500000       NaN       NaN       NaN
#
#         zori_4yc  zori_5yc
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ...          ...       ...
# 130047       NaN       NaN
# 130048       NaN       NaN
# 130049       NaN       NaN
# 130050       NaN       NaN
# 130051       NaN       NaN
#
# [130052 rows x 13 columns]

# %%
# save to csv
zori_county_long_clean.to_csv('data/zori_county_long_clean.csv', index=False)

# %%
# create a version of the df with only the most recent data

# find the most recent date
most_recent_date = zori_county_long_clean['date'].max()
# filter for most recent date
zori_county_most_recent_clean = zori_county_long_clean[zori_county_long_clean['date'] == most_recent_date]

# drop cols
zori_county_most_recent_clean.drop(columns=[
    'type',
    'zori_2yc',
    'zori_3yc',
    'zori_4yc'
], 
inplace=True
)

zori_county_most_recent_clean
# Out:
# /var/folders/jd/5wy1jytx2pg8j4jr12tl0k_m0000gq/T/ipykernel_32641/1365490567.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zori_county_most_recent_clean.drop(columns=[
#                           name   fips        lat         lng  pop_2023  \
# 128986  Los Angeles County, CA   6037  34.067886 -118.245990   9663345
# 128987         Cook County, IL  17031  41.869515  -87.757998   5087072
# 128988       Harris County, TX  48201  29.816889  -95.425716   4835125
# 128989     Maricopa County, AZ   4013  33.490147 -112.044016   4585871
# 128990    San Diego County, CA   6073  32.884418 -117.112348   3269973
# ...                        ...    ...        ...         ...       ...
# 130047     McKenzie County, ND  38053  47.815379 -103.249949     14252
# 130048    Archuleta County, CO   8007  37.240274 -107.089808     14189
# 130049       Blanco County, TX  48031  30.177148  -98.392080     13048
# 130050  Clear Creek County, CO   8019  39.713458 -105.532527      9147
# 130051      Lexington City, VA  51678  37.784392  -79.443722      7528
#
#              date         zori  zori_1yc  zori_5yc
# 128986 2025-02-28  2898.351766  0.041912  0.241724
# 128987 2025-02-28  2118.479524  0.054544  0.266043
# 128988 2025-02-28  1637.503955  0.021680  0.217986
# 128989 2025-02-28  1808.114958  0.008956  0.368055
# 128990 2025-02-28  3011.576644  0.030736  0.394775
# ...           ...          ...       ...       ...
# 130047 2025-02-28  1542.000000       NaN       NaN
# 130048 2025-02-28  1637.500000       NaN       NaN
# 130049 2025-02-28  1435.000000       NaN       NaN
# 130050 2025-02-28  1725.000000       NaN       NaN
# 130051 2025-02-28   847.500000       NaN       NaN
#
# [1066 rows x 9 columns]

# %%
# save to csv
zori_county_most_recent_clean.to_csv('data/zori_county_most_recent_clean.csv', index=False)

# %%
zori_county_most_recent_clean.columns
# Out:
# Index(['name', 'fips', 'lat', 'lng', 'pop_2023', 'date', 'zori', 'zori_1yc',
#        'zori_5yc'],
#       dtype='object')

# %%
# from zori_county_most_recent_clean, get the 90th and 10th percentile of zori_1yc
zori_county_most_recent_clean['zori_1yc'].quantile([0.1, 0.9])
# Out:
# 0.1    0.014022
# 0.9    0.082513
# Name: zori_1yc, dtype: float64
