# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# /Users/gabrielmelmed/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
url = "https://assets.ctfassets.net/jeox55pd4d8n/5ftdPCvJTzU3cFFiccdSA0/26b3aaf34a18555a4a76e05b506f6bcd/Apartment_List_Rent_Estimates_2024_09.csv"

# %%
https://assets.ctfassets.net/jeox55pd4d8n/5ftdPCvJTzU3cFFiccdSA0/26b3aaf34a18555a4a76e05b506f6bcd/Apartment_List_Rent_Estimates_2024_09.csv
https://assets.ctfassets.net/jeox55pd4d8n/2AQ7jbgJS7X3qAmDhkMZrn/2a2aa15d23e2cd9bd38ef169ccef2d94/Apartment_List_Rent_Estimates_2024_10.csv

# %%
df = pd.read_csv(url)

# %%
url = "https://www.apartmentlist.com/research/category/data-rent-estimates"
req = requests.get(url)

req.text
# Out:
# '<!DOCTYPE html>\n<html id="apartmentlist" xmlns="http://www.w3.org/1999/xhtml" lang="en">\n<head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<style>\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  display: flex;\n  flex-direction: column;\n  background: url(https://login.apartmentlist.com/__consent__/static/images/client_portal_background.png) center center / cover no-repeat fixed;\n}\n\n* {\n  box-sizing: border-box;\n}\n\n.css-rqz160 {\n  background-color: rgb(255, 255, 255);\n  border: 1px solid rgb(230, 230, 230);\n  border-radius: 16px;\n  display: flex;\n  flex-direction: column;\n  padding: 20px 55px 20px 55px;\n  width: 100%;\n  max-width: 550px;\n  margin: 24px;\n}\n\n.css-1v725xf {\n  height: 100%;\n  display: flex;\n  -webkit-box-align: center;\n  align-items: center;\n  -webkit-box-pack: center;\n  justify-content: center;\n}\n\n.css-1irx2pe {\n  height: 41px;\n  margin: 14px 0px 38px;\n}\n\n.css-terms {\n  text-align: center;\n  color: grey;\n 
# ...

# %%
df
# Out:
#       location_name location_type  location_fips_code  population       state  \
# 0     United States      National                   0   331097593         NaN
# 1     United States      National                   0   331097593         NaN
# 2     United States      National                   0   331097593         NaN
# 3        California         State                   6    39356104  California
# 4        California         State                   6    39356104  California
# ...             ...           ...                 ...         ...         ...
# 3556    Oakwood, GA          City             1357260        5132     Georgia
# 3557    Oakwood, GA          City             1357260        5132     Georgia
# 3558   Glendale, CO          City              830340        4580    Colorado
# 3559   Glendale, CO          City              830340        4580    Colorado
# 3560   Glendale, CO          City              830340        4580    Colorado
#
# ...
